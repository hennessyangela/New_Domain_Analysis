# %% [markdown]
# #### Summary

# %% [markdown]
# #### imports

# %%
import requests
import pandas as pd
from pprint import pprint
import pickle
from datetime import datetime
import time
import json
import whois
import itertools
import re
from colorama import init, Fore, Style
import xmltodict
import matplotlib.pyplot as plt
import networkx as nx
from tldextract import extract

# %% [markdown]
# #### Read in newly registered domains(NRD) from the last 10 days

# %%
newly_registered_domains=set()
nrd_url='https://cdn.jsdelivr.net/gh/hagezi/dns-blocklists@latest/adblock/nrds.10.txt'
response=requests.get(nrd_url)
response_text=response.text
lines=response_text.split('\n')
for line in lines:
    if line.startswith('||'):
        newly_registered_domains.add(line[2:-1])

# %%
print('Number of newly registered domains(in the past 10 days): {}'.format(len(newly_registered_domains)))
# Out:
# Number of newly registered domains(in the past 10 days): 997986

# %% [markdown]
# ### Now we'll look for possible suspicious domains by looking for certain keywords

# %%
possible_suspicious_domains=set()
keywords_for_suspicious_domains_keywords=['login','microsoft','paypal']
for domain in newly_registered_domains:
    for keyword in keywords_for_suspicious_domains_keywords:
        if keyword in domain:
            print('Possible suspicious domain:{}'.format(domain))
            possible_suspicious_domains.add(domain)
# Out:
# Possible suspicious domain:deelogin.com
# Possible suspicious domain:woodforest-online-login.cfd
# Possible suspicious domain:king365casinologin.info
# Possible suspicious domain:onabetlogin.com
# Possible suspicious domain:r777login.com
# Possible suspicious domain:kingslot777login.bet
# Possible suspicious domain:paypalcreidt.com
# Possible suspicious domain:tower88login.com
# Possible suspicious domain:paypalvredit.com
# Possible suspicious domain:analogintegrated.com
# Possible suspicious domain:lineslot77login.net
# Possible suspicious domain:b2alogin.com
# Possible suspicious domain:fun88login.in
# Possible suspicious domain:hollywoodlogin.web.za
# Possible suspicious domain:employeexpress-loginp7.shop
# Possible suspicious domain:ollo88login.net
# Possible suspicious domain:elang88login.co
# Possible suspicious domain:mediaslot77login.com
# Possible suspicious domain:login-mp.com
# Possible suspicious domain:paypalservices.net
# Possible suspicious domain:paycore-logint9.shop
# Possible suspicious domain:tiplogin.com
# Possible suspicious domain:analoginterface.io
# Possible suspicious domain:90jili-login.com.ph
# Possible suspicious domain:tanah189-login.com
# Possible suspicious domain:indonesialogin27.com
# Possible suspicious domain:ladang88login.com
# Possible suspicious domain:eelogin.co.uk
# Possible suspicious domain:microsoft-aub.com
# Possible suspicious domain:ketua4dlogin.org
# Possible suspicious domain:login-facebook.us
# Possible suspicious domain:salesforcelogins.com
# Possible suspicious domain:loginautoawala.xyz
# Possible suspicious domain:employeexpress-loginp5.shop
# Possible suspicious domain:abangda77login.com
# Possible suspicious domain:chatgptlogin.xyz
# Possible suspicious domain:dislogint.com
# Possible suspicious domain:loginkayabet99.icu
# Possible suspicious domain:login-sig-iforgot.com
# Possible suspicious domain:emaillogin.network
# Possible suspicious domain:login-gov-help.org
# Possible suspicious domain:paypal-payment.net
# Possible suspicious domain:abadi4dlogin.com
# Possible suspicious domain:pandaslot888login.net
# Possible suspicious domain:goceng99login.com
# Possible suspicious domain:loginopi4d.xyz
# Possible suspicious domain:loginmyaugov.org
# Possible suspicious domain:liveslot77login.com
# Possible suspicious domain:loginislanddesterminatingco.xyz
# Possible suspicious domain:panglima4dlogin.org
# Possible suspicious domain:loginbatman.net
# Possible suspicious domain:gowin138login.com
# Possible suspicious domain:lodi777-login.com.ph
# Possible suspicious domain:roket168login.com
# Possible suspicious domain:wow4dlogin.com
# Possible suspicious domain:paypal-accountbestatigung-swiss.biz
# Possible suspicious domain:bass99login.com
# Possible suspicious domain:chumbalogin.link
# Possible suspicious domain:makmur99login.net
# Possible suspicious domain:paypal-accountbestatigung-swiss.net
# Possible suspicious domain:login-eu.pw
# Possible suspicious domain:mail-co-mmufa-jp-am-bin-am-login.com
# Possible suspicious domain:microsoftstockprice.biz
# Possible suspicious domain:dana77login.com
# Possible suspicious domain:unggul77login.com
# Possible suspicious domain:elements-loginq1.shop
# Possible suspicious domain:final4dlogin.net
# Possible suspicious domain:tunai138login.com
# Possible suspicious domain:neraka88login.com
# Possible suspicious domain:loginradiuscdn.com
# Possible suspicious domain:pasang88login.co
# Possible suspicious domain:loginrt138.pro
# Possible suspicious domain:master78login.com
# Possible suspicious domain:login2327.homes
# Possible suspicious domain:venmologinusa.com
# Possible suspicious domain:login-santan.com
# Possible suspicious domain:casinoswithpaypal.com
# Possible suspicious domain:woodforest-online-login.net
# Possible suspicious domain:paypalcrdit.com
# Possible suspicious domain:luva-bet-login.com
# Possible suspicious domain:cibcloginsecure.com
# Possible suspicious domain:mfflogin.xyz
# Possible suspicious domain:santuy4dlogin.com
# Possible suspicious domain:paypal-accountbestatigung-swiss.com
# Possible suspicious domain:ollo88login.com
# Possible suspicious domain:itrustcapital-login.com
# Possible suspicious domain:jutawan4dlogin.net
# Possible suspicious domain:govloginatosau.org
# Possible suspicious domain:webhostlogin.com
# Possible suspicious domain:enviromaticsystems-onmicrosoft.com
# Possible suspicious domain:mania77login.com
# Possible suspicious domain:playslot138login.com
# Possible suspicious domain:loginlabs.net
# Possible suspicious domain:jalur77login.net
# Possible suspicious domain:tcslogin.app
# Possible suspicious domain:loginatoportals.org
# Possible suspicious domain:employeexpress-loginp4.shop
# Possible suspicious domain:mpl77login.net
# Possible suspicious domain:jalur77login.com
# Possible suspicious domain:jiliace-login.com.ph
# Possible suspicious domain:woodforest-online-login.com
# Possible suspicious domain:kaikoslotlogin.art
# Possible suspicious domain:beat88login.net
# Possible suspicious domain:microsoft-studio.com
# Possible suspicious domain:kaki4d-login.com
# Possible suspicious domain:login-plataform.fun
# Possible suspicious domain:mobilepay-login.net
# Possible suspicious domain:microsoft-audio.com
# Possible suspicious domain:spotifylogin.com
# Possible suspicious domain:login-sadabeil.com
# Possible suspicious domain:jaya-login.com
# Possible suspicious domain:microsoft-auto-gen.com
# Possible suspicious domain:employeexpress-loginp2.shop
# Possible suspicious domain:chatgptlogin.id
# Possible suspicious domain:logincard.co.in
# Possible suspicious domain:microsoftai.live
# Possible suspicious domain:login-settings.com
# Possible suspicious domain:loginsite.eu
# Possible suspicious domain:mawar77login.co
# Possible suspicious domain:ukklogin.net
# Possible suspicious domain:pandawa77login.com
# Possible suspicious domain:mpl4dlogin.com
# Possible suspicious domain:hokijplogin.co
# Possible suspicious domain:goolapplesoundfreepikmicrosoftnvidiaamdspotifyrazersamsungtesla.top
# Possible suspicious domain:employeexpress-logins1.shop
# Possible suspicious domain:logintolink.site
# Possible suspicious domain:leko88login.org
# Possible suspicious domain:hbo77login.com
# Possible suspicious domain:kera138login.net
# Possible suspicious domain:hokijplogin.net
# Possible suspicious domain:konco-88-login.site
# Possible suspicious domain:magnum168login.com
# Possible suspicious domain:itrustcapitallogin.net
# Possible suspicious domain:cuan99login.com
# Possible suspicious domain:skipton-login.com
# Possible suspicious domain:casino-logins.com
# Possible suspicious domain:goceng99login.net
# Possible suspicious domain:loginwebonlinne.com
# Possible suspicious domain:tato88login.com
# Possible suspicious domain:bcgame-login.org
# Possible suspicious domain:fairgocasino-login.com
# Possible suspicious domain:bidadari99login.net
# Possible suspicious domain:target777login.com
# Possible suspicious domain:777pub-login.com.ph
# Possible suspicious domain:routereloginm.net
# Possible suspicious domain:oakenlogins.life
# Possible suspicious domain:employeexpress-loginp3.shop
# Possible suspicious domain:imo88login.com
# Possible suspicious domain:loginsecure.net
# Possible suspicious domain:plogindecor.com
# Possible suspicious domain:paypalcreedit.com
# Possible suspicious domain:loginsmoobu.site
# Possible suspicious domain:gowin99login.com
# Possible suspicious domain:paypalcreditl.com
# Possible suspicious domain:sloki138login.com
# Possible suspicious domain:mawar99login.net
# Possible suspicious domain:wahana77login.org
# Possible suspicious domain:login-soport-icloud.us
# Possible suspicious domain:loginmyqov-csupelink.buzz
# Possible suspicious domain:mas888login.com
# Possible suspicious domain:uslogin.online
# Possible suspicious domain:koin38login.com
# Possible suspicious domain:microsoftautogen.net
# Possible suspicious domain:govloginauato.org
# Possible suspicious domain:slotking777login.org
# Possible suspicious domain:lcloud-apple-login.us
# Possible suspicious domain:corp-online-login-westpac.com
# Possible suspicious domain:mb8login.com
# Possible suspicious domain:login-bell.com
# Possible suspicious domain:superwin138login.com
# Possible suspicious domain:liveslot777login.net
# Possible suspicious domain:collectivehealthlogin.org
# Possible suspicious domain:bebek138login.net
# Possible suspicious domain:tower88login.org
# Possible suspicious domain:situs4dlogin.co
# Possible suspicious domain:securecloudlogin.com
# Possible suspicious domain:connect-login.us
# Possible suspicious domain:magnum88login.com
# Possible suspicious domain:employeexpress-logina9.shop
# Possible suspicious domain:paypalorder.info
# Possible suspicious domain:percaya4d-login.org
# Possible suspicious domain:duniaslot888login.org
# Possible suspicious domain:mpl77login.com
# Possible suspicious domain:login-auatothgov.org
# Possible suspicious domain:loginrcu.info
# Possible suspicious domain:wild168login.net
# Possible suspicious domain:ezyplogin.com
# Possible suspicious domain:bloginbest.in
# Possible suspicious domain:cuan69login.net
# Possible suspicious domain:login-security-department.com
# Possible suspicious domain:lodibet-login.com.ph
# Possible suspicious domain:loginmygovau.org
# Possible suspicious domain:god55login.com
# Possible suspicious domain:microsoft-hk3.xyz
# Possible suspicious domain:awan88login.com
# Possible suspicious domain:loginsensa838.xyz
# Possible suspicious domain:helpdesk-qbo-login-accounts.online
# Possible suspicious domain:microsoftsecurefileprotect.sbs
# Possible suspicious domain:ml77login.com
# Possible suspicious domain:loginmideatoto.xyz
# Possible suspicious domain:hantulogin.life
# Possible suspicious domain:klikbet77newlogin.xyz
# Possible suspicious domain:1win-login.today
# Possible suspicious domain:juara168login.com
# Possible suspicious domain:warkop77login.net
# Possible suspicious domain:tdlinklogin.net
# Possible suspicious domain:logingj55.com
# Possible suspicious domain:uionline-detma-logine2.shop
# Possible suspicious domain:maxslot888login.org
# Possible suspicious domain:helpmicrosofts.com
# Possible suspicious domain:mybigpictureloanslogin.com
# Possible suspicious domain:master388login.com
# Possible suspicious domain:pentera-onelogin.com
# Possible suspicious domain:loginpingtoto.pro
# Possible suspicious domain:kycpanlogin.in
# Possible suspicious domain:logingovatos.org
# Possible suspicious domain:tunai138login.net
# Possible suspicious domain:uionline-detma-logine8.shop
# Possible suspicious domain:tante77login.co
# Possible suspicious domain:maxbet168login.net
# Possible suspicious domain:loginwaktogel.net
# Possible suspicious domain:ladang77login.net
# Possible suspicious domain:loginfacebook.com.tr
# Possible suspicious domain:laris888login.com
# Possible suspicious domain:galera-bet-login.com
# Possible suspicious domain:loginpingtoto.click
# Possible suspicious domain:evri-login.xyz
# Possible suspicious domain:revolutlogin.com
# Possible suspicious domain:lord77login.com
# Possible suspicious domain:microsoft0nline0ffice365.com
# Possible suspicious domain:mayorqqlogin.com
# Possible suspicious domain:yowestogel88login.com
# Possible suspicious domain:maxbet138login.net
# Possible suspicious domain:loginksab00.live
# Possible suspicious domain:wave-login.info
# Possible suspicious domain:paycor-login.one
# Possible suspicious domain:paypal-assistances.com
# Possible suspicious domain:login-connexion.info
# Possible suspicious domain:hemat77login.com
# Possible suspicious domain:venus88login.net
# Possible suspicious domain:microsoft-global.com
# Possible suspicious domain:uionline-detma-loginw5.shop
# Possible suspicious domain:lumi77login.com
# Possible suspicious domain:aston168login.org
# Possible suspicious domain:toto77login.org
# Possible suspicious domain:mediaslotlogin.org
# Possible suspicious domain:jototestmicrosoft365.com
# Possible suspicious domain:neraka88login.net
# Possible suspicious domain:logindunia805.com
# Possible suspicious domain:paycore-loginr8.shop
# Possible suspicious domain:petir4dlogin.co
# Possible suspicious domain:paypal-ungewohnlicheaktivitat.com
# Possible suspicious domain:logincasinoaustralia.com
# Possible suspicious domain:tango4dlogin.com
# Possible suspicious domain:employriloginintro.org
# Possible suspicious domain:asbnetlogins.com
# Possible suspicious domain:loginibukota303.com
# Possible suspicious domain:splean-login.com
# Possible suspicious domain:tloging.com
# Possible suspicious domain:microsoft365.buzz
# Possible suspicious domain:officelogin.site
# Possible suspicious domain:gold99login.com
# Possible suspicious domain:indonesialogin29.com
# Possible suspicious domain:beton123login.com
# Possible suspicious domain:pandaslot888login.com
# Possible suspicious domain:tango4dlogin.net
# Possible suspicious domain:nice88-login.com.ph
# Possible suspicious domain:uionline-detma-logine6.shop
# Possible suspicious domain:petir77login.co
# Possible suspicious domain:clbcloginacct024758.com
# Possible suspicious domain:smoobulogin.com
# Possible suspicious domain:loginmicrosoftonlinekmsi.com
# Possible suspicious domain:loginmicrosoftonlinekmsi.com
# Possible suspicious domain:opencatalogingrules.org
# Possible suspicious domain:malam4dlogin.net
# Possible suspicious domain:paypal-ungewohnlicheaktivitat.name
# Possible suspicious domain:pintuutamalogin.info
# Possible suspicious domain:abangda77login.org
# Possible suspicious domain:logindrive.top
# Possible suspicious domain:lord77login.net
# Possible suspicious domain:get-login.com
# Possible suspicious domain:gmailemail-login.email
# Possible suspicious domain:bet777slotlogin.com
# Possible suspicious domain:ifhrmslogin.in
# Possible suspicious domain:logingovauato.org
# Possible suspicious domain:hollywoodlogin.org.za
# Possible suspicious domain:psg888login.net
# Possible suspicious domain:loginketuaslot.com
# Possible suspicious domain:login.feedback
# Possible suspicious domain:employeexpress-logino9.shop
# Possible suspicious domain:blangkon77login.com
# Possible suspicious domain:nexlogin.com
# Possible suspicious domain:icloud-login.info
# Possible suspicious domain:connect-bill-comcast-login.com
# Possible suspicious domain:indonesialogin26.com
# Possible suspicious domain:myaccount-login.com
# Possible suspicious domain:paypalcare.com
# Possible suspicious domain:logindatukgaming.com
# Possible suspicious domain:jilino1-login.com.ph
# Possible suspicious domain:imbaslot-login.net
# Possible suspicious domain:login-strems-outlook.com
# Possible suspicious domain:bmx-login.com
# Possible suspicious domain:loginbrwsc.net
# Possible suspicious domain:microsoft-office.love
# Possible suspicious domain:kakaclublogin.com
# Possible suspicious domain:raksasa77login.com
# Possible suspicious domain:microsoftonline-europe.com
# Possible suspicious domain:paycore-logint1.shop
# Possible suspicious domain:employeexpress-logina8.shop
# Possible suspicious domain:microsoft365expert.com
# Possible suspicious domain:supportt-idlogin.info
# Possible suspicious domain:americanexpressloginus.com
# Possible suspicious domain:betvisa-login.com.ph
# Possible suspicious domain:kita4dlogin.net
# Possible suspicious domain:oakenlogin.life
# Possible suspicious domain:gold777login.co
# Possible suspicious domain:jili777-login.com.ph
# Possible suspicious domain:navlogin-securefiles-access.co
# Possible suspicious domain:login-krekan.com
# Possible suspicious domain:loginsection.com
# Possible suspicious domain:superwin77login.net
# Possible suspicious domain:paypalcreditt.com
# Possible suspicious domain:mcgowanplaymicrosoft.com
# Possible suspicious domain:logincimol88.org
# Possible suspicious domain:nix777login.net
# Possible suspicious domain:loginpersik4d.info
# Possible suspicious domain:mpl888login.com
# Possible suspicious domain:bandar69login.co
# Possible suspicious domain:kudasakti168-login.com
# Possible suspicious domain:hollywoodlogin.africa
# Possible suspicious domain:uionline-detma-logine7.shop
# Possible suspicious domain:loginbpduvida.online
# Possible suspicious domain:qqmercylogin.link
# Possible suspicious domain:bebek138login.com
# Possible suspicious domain:lineslot77login.com
# Possible suspicious domain:augovservice-login.com
# Possible suspicious domain:winbox-login.asia
# Possible suspicious domain:mwvlogin.net
# Possible suspicious domain:kampung88login.com
# Possible suspicious domain:paypalcrecit.com
# Possible suspicious domain:uionline-detma-loginr3.shop
# Possible suspicious domain:capitaltraderlogin.org
# Possible suspicious domain:uionline-detma-logine4.shop
# Possible suspicious domain:x-login.xyz
# Possible suspicious domain:projplogin.com
# Possible suspicious domain:kanjeng88login.net
# Possible suspicious domain:paycore-loginr6.shop
# Possible suspicious domain:auservicelogin-mygov.com
# Possible suspicious domain:peso888-login.com.ph
# Possible suspicious domain:tg777-login.com.ph
# Possible suspicious domain:microsoftssupport.com
# Possible suspicious domain:login-instagram.us
# Possible suspicious domain:casino88login.co
# Possible suspicious domain:paypalrecuperation-europe.com
# Possible suspicious domain:virus77login.com
# Possible suspicious domain:petir888login.co
# Possible suspicious domain:hantulogin.xyz
# Possible suspicious domain:kiafinancelogin.link
# Possible suspicious domain:paypalcom.ru
# Possible suspicious domain:ncbupdatelogin.org
# Possible suspicious domain:loginote.com
# Possible suspicious domain:uionline-detma-loginw6.shop
# Possible suspicious domain:id-login.com
# Possible suspicious domain:tpplinklogin.net
# Possible suspicious domain:alibaba4dlogin.com
# Possible suspicious domain:royallogin.buzz
# Possible suspicious domain:hollywoodloginguide.com
# Possible suspicious domain:paycorlogin.store
# Possible suspicious domain:orilogin.net
# Possible suspicious domain:inboxlogin-mygov.com
# Possible suspicious domain:sabu99-login.com
# Possible suspicious domain:ssoidrajasthanlogin.com
# Possible suspicious domain:govatologin.org
# Possible suspicious domain:sobat77login.com
# Possible suspicious domain:microsoftrewards.co
# Possible suspicious domain:ph365-login.com.ph
# Possible suspicious domain:megaslots888login.com
# Possible suspicious domain:loginpug4d.today
# Possible suspicious domain:loginsearchsecure.xyz
# Possible suspicious domain:paycore-loginr3.shop
# Possible suspicious domain:akseslogin.site
# Possible suspicious domain:winboxlogin8.com
# Possible suspicious domain:slot633login.com
# Possible suspicious domain:mqlogin.net
# Possible suspicious domain:playwin99login.com
# Possible suspicious domain:duniaslot888login.com
# Possible suspicious domain:ineos-microsoft.com
# Possible suspicious domain:indonesialogin30.com
# Possible suspicious domain:onelogin-flb2.top
# Possible suspicious domain:microsoftshareprice.club
# Possible suspicious domain:paypalcreadit.com
# Possible suspicious domain:paypal-accountbestatigung-swiss.info
# Possible suspicious domain:slotking96login.com
# Possible suspicious domain:playslot888login.net
# Possible suspicious domain:paycor-login.org
# Possible suspicious domain:logins.cc
# Possible suspicious domain:casinoplus-login.com.ph
# Possible suspicious domain:conferma-paypal.com
# Possible suspicious domain:paypal-accountbestatigung-swiss.name
# Possible suspicious domain:imbaslot-login.com
# Possible suspicious domain:paypal-pay.net
# Possible suspicious domain:uionline-detma-loginw4.shop
# Possible suspicious domain:jilievo888-login.com.ph
# Possible suspicious domain:setia77login.com
# Possible suspicious domain:303pedialogin.com
# Possible suspicious domain:ailogin.xyz
# Possible suspicious domain:paycore-loginr7.shop
# Possible suspicious domain:harta777login.com
# Possible suspicious domain:mygovloginau.org
# Possible suspicious domain:uionline-detma-loginq7.shop
# Possible suspicious domain:uionline-detma-loginq9.shop
# Possible suspicious domain:kingbet123login.org
# Possible suspicious domain:loginlcloud-find.xyz
# Possible suspicious domain:vehollargloginful.com
# Possible suspicious domain:baboologin.online
# Possible suspicious domain:paypal-unrestricted.com
# Possible suspicious domain:eclbetlogin.com
# Possible suspicious domain:microsoftautogen.com
# Possible suspicious domain:bareng4dlogin.net
# Possible suspicious domain:eyang77login.net
# Possible suspicious domain:uionline-detma-loginw7.shop
# Possible suspicious domain:login4d-gacor.shop
# Possible suspicious domain:loginbensintoto.com
# Possible suspicious domain:loginaccessmantulwd808.com
# Possible suspicious domain:woodforest-online-login.org
# Possible suspicious domain:client-login-service.com
# Possible suspicious domain:lazawin-login.com
# Possible suspicious domain:loginekef00.live
# Possible suspicious domain:loginingat88.xyz
# Possible suspicious domain:tplinkllogin.net
# Possible suspicious domain:wwwfox888viplogin.info
# Possible suspicious domain:logingovouato.org
# Possible suspicious domain:employeexpress-loginp9.shop
# Possible suspicious domain:minfu-paypal.net
# Possible suspicious domain:pintuutamalogin.pro
# Possible suspicious domain:tplinkloginn.net
# Possible suspicious domain:1winlogin.co.in
# Possible suspicious domain:routerloginwiz.net
# Possible suspicious domain:bagong99login.net
# Possible suspicious domain:login.xin
# Possible suspicious domain:cuan99login.net
# Possible suspicious domain:cuan888login.com
# Possible suspicious domain:petir888login.net
# Possible suspicious domain:paypal-ungewohnlicheaktivitat.org
# Possible suspicious domain:localogin.top
# Possible suspicious domain:winuniquecasinologin.com
# Possible suspicious domain:hollywoodlogin.net.za
# Possible suspicious domain:mawar168login.net
# Possible suspicious domain:loginexa.org
# Possible suspicious domain:juara99login.net
# Possible suspicious domain:employeexpress-logina4.shop
# Possible suspicious domain:loginkswg37.live
# Possible suspicious domain:nanas88login.com
# Possible suspicious domain:loginalert-x.com
# Possible suspicious domain:bosku138login.net
# Possible suspicious domain:loginogovato.org
# Possible suspicious domain:loginfollowmyhealth.com
# Possible suspicious domain:paypalcreddit.com
# Possible suspicious domain:boardsrepmicrosoft.com
# Possible suspicious domain:sun138login.com
# Possible suspicious domain:maxslot888login.com
# Possible suspicious domain:loginbajaubet.com
# Possible suspicious domain:loginex.com.mx
# Possible suspicious domain:myauatologin-gov.org
# Possible suspicious domain:warkop77login.com
# Possible suspicious domain:paypal-accountbestatigung-swiss.org
# Possible suspicious domain:sitemicrosoft.org
# Possible suspicious domain:nekoslot888login.com
# Possible suspicious domain:brazino777login.com.br
# Possible suspicious domain:myinlogin-user.net
# Possible suspicious domain:logintechno.com
# Possible suspicious domain:microsoft-automotive.com
# Possible suspicious domain:midas88login.com
# Possible suspicious domain:fawazsteelmicrosoftmarketing.buzz
# Possible suspicious domain:dream99login.com
# Possible suspicious domain:angsa77login.com
# Possible suspicious domain:onelogin-en.com
# Possible suspicious domain:8k8-casino-login.net
# Possible suspicious domain:bali4dlogin.com
# Possible suspicious domain:td-authlogin.com
# Possible suspicious domain:bangsawan77login.com
# Possible suspicious domain:lotus365-quickloginid.agency
# Possible suspicious domain:playslot888login.com
# Possible suspicious domain:lonestarlogin.top
# Possible suspicious domain:kingbet123login.com
# Possible suspicious domain:cvsotcorderonlinelogin.com
# Possible suspicious domain:acess-login.com
# Possible suspicious domain:mainslot99login.com
# Possible suspicious domain:healthclub-login.com
# Possible suspicious domain:superace88-login.com.ph
# Possible suspicious domain:trlogin.net
# Possible suspicious domain:akslot88login.net
# Possible suspicious domain:bitmart-login-official.com
# Possible suspicious domain:login-online-office.com
# Possible suspicious domain:warteg4dlogin.com
# Possible suspicious domain:paypal-ungewohnlicheaktivitat.biz
# Possible suspicious domain:honglogin.com
# Possible suspicious domain:pasang138login.com
# Possible suspicious domain:login-auth.lol
# Possible suspicious domain:logintolink.shop
# Possible suspicious domain:vbetbonuslogin.com
# Possible suspicious domain:loginform.pro
# Possible suspicious domain:sun77login.com
# Possible suspicious domain:dispute-login.ru
# Possible suspicious domain:paypal-ungewohnlicheaktivitat.info
# Possible suspicious domain:oauth2login.com
# Possible suspicious domain:employeexpress-loginp8.shop

# %%
print('Number of potentially suspicious domains: {}'.format(len(possible_suspicious_domains)))
# Out:
# Number of potentially suspicious domains: 506

# %% [markdown]
# #### Spot checking some of these domains in VT, some are flagged for phishing:
#
# #### login-soport-icloud[.]us
#
# #### paypalcreedit[.]com

# %% [markdown]
# #### Grab whois info for the potentially suspicious domains

# %%
creation_dates=[]
expiration_dates=[]
updated_dates=[]
name_servers=[]

domains=[]
for domain in possible_suspicious_domains:
    time.sleep(7)
    print('Looking up: {}'.format(domain))
    domains.append(domain)
    w = whois.whois(domain)
    pprint(w)
    creation_dates.append(w.get('creation_date',None))
    expiration_dates.append(w.get('expiration_date',None))
    updated_dates.append(w.get('updated_date',None))
    name_servers.append(w.get('name_servers',None))
# Out:
# Looking up: login-eu.pw
# {'address': None,
#  'city': None,
#  'country': None,
#  'creation_date': datetime.datetime(2024, 3, 28, 20, 16, 56),
#  'dnssec': 'unsigned',
#  'domain_name': 'LOGIN-EU.PW',
#  'emails': 'abuse@beget.com',
#  'expiration_date': datetime.datetime(2025, 3, 28, 23, 59, 59),
#  'name': None,
#  'name_servers': ['NS2.BEGET.PRO',
#                   'NS2.BEGET.COM',
#                   'NS1.BEGET.PRO',
#                   'NS1.BEGET.COM'],
#  'org': None,
#  'referral_url': None,
#  'registrant_postal_code': None,
#  'registrar': 'Beget LLC',
#  'state': None,
#  'status': ['serverHold https://icann.org/epp#serverHold',
#             'serverTransferProhibited '
#             'https://icann.org/epp#serverTransferProhibited',
#             'clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited'],
#  'updated_date': datetime.datetime(2024, 4, 2, 20, 21, 29),
#  'whois_server': 'whois.beget.com'}
# Looking up: microsoft365.buzz
# {'address': ['REDACTED FOR PRIVACY', '1928 E. Highland Ave. Ste F104 PMB# 255'],
#  'city': ['REDACTED FOR PRIVACY', 'Phoenix'],
#  'country': 'US',
#  'creation_date': [datetime.datetime(2024, 4, 7, 15, 11, 53),
#                    datetime.datetime(2024, 4, 7, 7, 0)],
#  'dnssec': 'unsigned',
#  'domain_name': 'microsoft365.buzz',
#  'emails': ['abuse@namesilo.com',
#             'pw-0a8ad873aacb98a4fa9be882a96c38ff@privacyguardian.org'],
#  'expiration_date': [datetime.datetime(2025, 4, 7, 15, 11, 53),
#                      datetime.datetime(2025, 4, 7, 7, 0)],
#  'name': 'REDACTED FOR PRIVACY',
#  'name_servers': ['sean.ns.cloudflare.com',
#                   'kira.ns.cloudflare.com',
#                   'KIRA.NS.CLOUDFLARE.COM',
#                   'SEAN.NS.CLOUDFLARE.COM'],
#  'org': 'PrivacyGuardian.org llc',
#  'referral_url': None,
#  'registrant_postal_code': ['REDACTED FOR PRIVACY', '85016'],
#  'registrar': 'NameSilo, LLC',
#  'state': 'AZ',
#  'status': ['clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited',
#             'serverTransferProhibited '
#             'https://icann.org/epp#serverTransferProhibited',
#             'addPeriod https://icann.org/epp#addPeriod',
#             'clientTransferProhibited '
#             'https://www.icann.org/epp#clientTransferProhibited'],
#  'updated_date': [datetime.datetime(2024, 4, 7, 15, 25, 15),
#                   datetime.datetime(2024, 4, 8, 7, 0)],
#  'whois_server': 'whois.namesilo.com'}
# Looking up: bidadari99login.net
# {'address': '1928 E. Highland Ave. Ste F104 PMB# 255',
#  'city': 'Phoenix',
#  'country': 'US',
#  'creation_date': [datetime.datetime(2024, 4, 3, 10, 18, 48),
#                    datetime.datetime(2024, 4, 3, 7, 0)],
#  'dnssec': 'unsigned',
#  'domain_name': ['BIDADARI99LOGIN.NET', 'bidadari99login.net'],
#  'emails': ['abuse@namesilo.com',
#             'pw-50240952357833c5339b2fa22527cea6@privacyguardian.org'],
#  'expiration_date': [datetime.datetime(2025, 4, 3, 10, 18, 48),
#                      datetime.datetime(2025, 4, 3, 7, 0)],
#  'name': 'REDACTED FOR PRIVACY',
#  'name_servers': ['NS1.DNSOWL.COM', 'NS2.DNSOWL.COM', 'NS3.DNSOWL.COM'],
#  'org': 'PrivacyGuardian.org llc',
#  'referral_url': None,
#  'registrant_postal_code': '85016',
#  'registrar': 'NameSilo, LLC',
#  'state': 'AZ',
#  'status': ['clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited',
#             'clientTransferProhibited '
#             'https://www.icann.org/epp#clientTransferProhibited'],
#  'updated_date': [datetime.datetime(2024, 4, 3, 10, 18, 48),
#                   datetime.datetime(2024, 4, 3, 7, 0)],
#  'whois_server': 'whois.namesilo.com'}
# Looking up: klikbet77newlogin.xyz
# {'address': 'Kalkofnsvegur 2',
#  'city': 'Reykjavik',
#  'country': 'IS',
#  'creation_date': datetime.datetime(2024, 4, 6, 9, 2, 21),
#  'dnssec': 'unsigned',
#  'domain_name': ['KLIKBET77NEWLOGIN.XYZ', 'klikbet77newlogin.xyz'],
#  'emails': ['abuse@namecheap.com',
#             '12311fc444b14fc18e8a9750b4087780.protect@withheldforprivacy.com'],
#  'expiration_date': [datetime.datetime(2025, 4, 6, 23, 59, 59),
#                      datetime.datetime(2025, 4, 6, 9, 2, 21)],
#  'name': 'Redacted for Privacy',
#  'name_servers': ['DNS1.NAMECHEAPHOSTING.COM',
#                   'DNS2.NAMECHEAPHOSTING.COM',
#                   'dns1.namecheaphosting.com',
#                   'dns2.namecheaphosting.com'],
#  'org': 'Privacy service provided by Withheld for Privacy ehf',
#  'referral_url': None,
#  'registrant_postal_code': '101',
#  'registrar': 'NAMECHEAP INC',
#  'state': 'Capital Region',
#  'status': ['serverTransferProhibited '
#             'https://icann.org/epp#serverTransferProhibited',
#             'clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited',
#             'addPeriod https://icann.org/epp#addPeriod'],
#  'updated_date': [datetime.datetime(2024, 4, 6, 9, 2, 24),
#                   datetime.datetime(1, 1, 1, 0, 0)],
#  'whois_server': 'whois.namecheap.com'}
# Looking up: microsoftautogen.net
# {'address': 'REDACTED FOR PRIVACY',
#  'city': 'REDACTED FOR PRIVACY',
#  'country': 'US',
#  'creation_date': datetime.datetime(2023, 9, 27, 6, 46, 17),
#  'dnssec': 'unsigned',
#  'domain_name': ['MICROSOFTAUTOGEN.NET', 'microsoftautogen.net'],
#  'emails': 'abuse-complaints@squarespace.com',
#  'expiration_date': datetime.datetime(2024, 9, 27, 6, 46, 17),
#  'name': 'REDACTED FOR PRIVACY',
#  'name_servers': ['DNS1.P09.NSONE.NET',
#                   'DNS2.P09.NSONE.NET',
#                   'DNS3.P09.NSONE.NET',
#                   'DNS4.P09.NSONE.NET',
#                   'NS01.SQUARESPACEDNS.COM',
#                   'NS02.SQUARESPACEDNS.COM',
#                   'NS03.SQUARESPACEDNS.COM',
#                   'NS04.SQUARESPACEDNS.COM',
#                   'ns03.squarespacedns.com',
#                   'ns02.squarespacedns.com',
#                   'dns2.p09.nsone.net',
#                   'dns4.p09.nsone.net',
#                   'dns1.p09.nsone.net',
#                   'dns3.p09.nsone.net',
#                   'ns04.squarespacedns.com',
#                   'ns01.squarespacedns.com'],
#  'org': None,
#  'referral_url': None,
#  'registrant_postal_code': 'REDACTED FOR PRIVACY',
#  'registrar': 'Squarespace Domains LLC',
#  'state': 'IL',
#  'status': ['ok https://icann.org/epp#ok', 'ok http://www.icann.org/epp#ok'],
#  'updated_date': [datetime.datetime(2024, 4, 3, 23, 45, 2),
#                   datetime.datetime(2024, 4, 3, 23, 45, 2, 904040)],
#  'whois_server': 'whois.squarespace.domains'}
# Looking up: hollywoodlogin.africa
# {'address': ['REDACTED', 'REDACTED FOR PRIVACY'],
#  'city': ['REDACTED', 'REDACTED FOR PRIVACY'],
#  'country': 'PK',
#  'creation_date': datetime.datetime(2024, 3, 29, 22, 56, 47),
#  'dnssec': 'unsigned',
#  'domain_name': 'hollywoodlogin.africa',
#  'emails': 'abuse@registrar.eu',
#  'expiration_date': datetime.datetime(2025, 3, 29, 22, 56, 47),
#  'name': ['REDACTED', 'REDACTED FOR PRIVACY'],
#  'name_servers': ['wren.ns.cloudflare.com', 'margo.ns.cloudflare.com'],
#  'org': None,
#  'referral_url': None,
#  'registrant_postal_code': ['REDACTED', 'REDACTED FOR PRIVACY'],
#  'registrar': 'Hosting Concepts B.V. d/b/a Registrar.eu',
#  'state': ['REDACTED', 'Punjab'],
#  'status': ['clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited',
#             'ok https://icann.org/epp#ok'],
#  'updated_date': [datetime.datetime(2024, 3, 30, 21, 41, 30),
#                   datetime.datetime(2024, 3, 30, 22, 41, 33)],
#  'whois_server': 'whois.registrar.eu'}
# Looking up: employeexpress-loginp5.shop
# {'address': None,
#  'city': None,
#  'country': 'US',
#  'creation_date': datetime.datetime(2024, 3, 29, 20, 8, 44),
#  'dnssec': 'unsigned',
#  'domain_name': 'EMPLOYEEXPRESS-LOGINP5.SHOP',
#  'emails': 'abuse-contact@sav.com',
#  'expiration_date': datetime.datetime(2025, 3, 29, 23, 59, 59),
#  'name': None,
#  'name_servers': ['CULLEN.NS.CLOUDFLARE.COM', 'LIA.NS.CLOUDFLARE.COM'],
#  'org': None,
#  'referral_url': None,
#  'registrant_postal_code': None,
#  'registrar': 'Sav.com, LLC',
#  'state': 'IL',
#  'status': 'clientTransferProhibited '
#            'https://icann.org/epp#clientTransferProhibited',
#  'updated_date': datetime.datetime(2024, 3, 29, 20, 51, 4),
#  'whois_server': 'https://whois.virtualcloud.co/'}
# Looking up: tango4dlogin.net
# {'address': '1928 E. Highland Ave. Ste F104 PMB# 255',
#  'city': 'Phoenix',
#  'country': 'US',
#  'creation_date': [datetime.datetime(2024, 4, 5, 6, 40, 43),
#                    datetime.datetime(2024, 4, 4, 7, 0)],
#  'dnssec': 'unsigned',
#  'domain_name': ['TANGO4DLOGIN.NET', 'tango4dlogin.net'],
#  'emails': ['abuse@namesilo.com',
#             'pw-7c7842c20f99095e1cd81f6cbffacd2b@privacyguardian.org'],
#  'expiration_date': [datetime.datetime(2025, 4, 5, 6, 40, 43),
#                      datetime.datetime(2025, 4, 4, 7, 0)],
#  'name': 'REDACTED FOR PRIVACY',
#  'name_servers': ['NS1.DNSOWL.COM', 'NS2.DNSOWL.COM', 'NS3.DNSOWL.COM'],
#  'org': 'PrivacyGuardian.org llc',
#  'referral_url': None,
#  'registrant_postal_code': '85016',
#  'registrar': 'NameSilo, LLC',
#  'state': 'AZ',
#  'status': ['clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited',
#             'clientTransferProhibited '
#             'https://www.icann.org/epp#clientTransferProhibited'],
#  'updated_date': [datetime.datetime(2024, 4, 5, 6, 40, 43),
#                   datetime.datetime(2024, 4, 5, 7, 0)],
#  'whois_server': 'whois.namesilo.com'}
# Looking up: bitmart-login-official.com
# {'address': 'REDACTED FOR PRIVACY',
#  'city': 'REDACTED FOR PRIVACY',
#  'country': 'BR',
#  'creation_date': datetime.datetime(2023, 3, 25, 2, 22, 1),
#  'dnssec': 'unsigned',
#  'domain_name': 'BITMART-LOGIN-OFFICIAL.COM',
#  'emails': 'domainabuse@tucows.com',
#  'expiration_date': [datetime.datetime(2025, 3, 25, 2, 22, 1),
#                      datetime.datetime(2024, 3, 25, 2, 22, 1)],
#  'name': 'REDACTED FOR PRIVACY',
#  'name_servers': ['NS1.RENEWYOURNAME.NET',
#                   'NS2.RENEWYOURNAME.NET',
#                   'ns1.renewyourname.net',
#                   'ns2.renewyourname.net'],
#  'org': 'REDACTED FOR PRIVACY',
#  'referral_url': None,
#  'registrant_postal_code': 'REDACTED FOR PRIVACY',
#  'registrar': 'TUCOWS, INC.',
#  'state': 'GO',
#  'status': 'ok https://icann.org/epp#ok',
#  'updated_date': datetime.datetime(2024, 3, 29, 6, 57, 46),
#  'whois_server': 'whois.tucows.com'}
# Looking up: bet777slotlogin.com
# {'address': 'Kalkofnsvegur 2',
#  'city': 'Reykjavik',
#  'country': 'IS',
#  'creation_date': datetime.datetime(2024, 4, 3, 3, 49, 28),
#  'dnssec': 'unsigned',
#  'domain_name': ['BET777SLOTLOGIN.COM', 'bet777slotlogin.com'],
#  'emails': ['abuse@namecheap.com',
#             '6f71246f046046de98a603ec605a4ed8.protect@withheldforprivacy.com'],
#  'expiration_date': datetime.datetime(2025, 4, 3, 3, 49, 28),
#  'name': 'Redacted for Privacy',
#  'name_servers': ['BARBARA.NS.CLOUDFLARE.COM',
#                   'LENNON.NS.CLOUDFLARE.COM',
#                   'barbara.ns.cloudflare.com',
#                   'lennon.ns.cloudflare.com'],
#  'org': 'Privacy service provided by Withheld for Privacy ehf',
#  'referral_url': None,
#  'registrant_postal_code': '101',
#  'registrar': 'NAMECHEAP INC',
#  'state': 'Capital Region',
#  'status': 'clientTransferProhibited '
#            'https://icann.org/epp#clientTransferProhibited',
#  'updated_date': [datetime.datetime(2024, 4, 3, 4, 3, 18),
#                   datetime.datetime(1, 1, 1, 0, 0)],
#  'whois_server': 'whois.namecheap.com'}
# Looking up: enviromaticsystems-onmicrosoft.com
# {'address': ['DomainsByProxy.com', '2155 E Warner Rd'],
#  'city': 'Tempe',
#  'country': 'US',
#  'creation_date': [datetime.datetime(2024, 4, 3, 12, 12, 3),
#                    datetime.datetime(2024, 4, 3, 7, 12, 3)],
#  'dnssec': 'unsigned',
#  'domain_name': ['ENVIROMATICSYSTEMS-ONMICROSOFT.COM',
#                  'enviromaticsystems-onmicrosoft.com'],
#  'emails': 'abuse@wildwestdomains.com',
#  'expiration_date': [datetime.datetime(2025, 4, 3, 12, 12, 3),
#                      datetime.datetime(2025, 4, 3, 7, 12, 3)],
#  'name': 'Registration Private',
#  'name_servers': ['NS1.BDM.MICROSOFTONLINE.COM', 'NS2.BDM.MICROSOFTONLINE.COM'],
#  'org': 'Domains By Proxy, LLC',
#  'referral_url': None,
#  'registrant_postal_code': '85284',
#  'registrar': 'Wild West Domains, LLC',
#  'state': 'Arizona',
#  'status': ['clientDeleteProhibited '
#             'https://icann.org/epp#clientDeleteProhibited',
#             'clientRenewProhibited https://icann.org/epp#clientRenewProhibited',
#             'clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited',
#             'clientUpdateProhibited '
#             'https://icann.org/epp#clientUpdateProhibited'],
#  'updated_date': [datetime.datetime(2024, 4, 3, 12, 12, 4),
#                   datetime.datetime(2024, 4, 3, 7, 12, 4)],
#  'whois_server': 'whois.wildwestdomains.com'}
# Looking up: hbo77login.com
# {'address': '1928 E. Highland Ave. Ste F104 PMB# 255',
#  'city': 'Phoenix',
#  'country': 'US',
#  'creation_date': [datetime.datetime(2024, 4, 5, 9, 27),
#                    datetime.datetime(2024, 4, 5, 7, 0)],
#  'dnssec': 'unsigned',
#  'domain_name': ['HBO77LOGIN.COM', 'hbo77login.com'],
#  'emails': ['abuse@namesilo.com',
#             'pw-a9e74646e9bd86525a65fb11e982c575@privacyguardian.org'],
#  'expiration_date': [datetime.datetime(2025, 4, 5, 9, 27),
#                      datetime.datetime(2025, 4, 5, 7, 0)],
#  'name': 'REDACTED FOR PRIVACY',
#  'name_servers': ['NS1.DNSOWL.COM', 'NS2.DNSOWL.COM', 'NS3.DNSOWL.COM'],
#  'org': 'PrivacyGuardian.org llc',
#  'referral_url': None,
#  'registrant_postal_code': '85016',
#  'registrar': 'NameSilo, LLC',
#  'state': 'AZ',
#  'status': ['clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited',
#             'clientTransferProhibited '
#             'https://www.icann.org/epp#clientTransferProhibited'],
#  'updated_date': [datetime.datetime(2024, 4, 5, 9, 27),
#                   datetime.datetime(2024, 4, 5, 7, 0)],
#  'whois_server': 'whois.namesilo.com'}
# Looking up: augovservice-login.com
# {'address': '54 Kooljak Rd',
#  'city': 'Abbey',
#  'country': 'AU',
#  'creation_date': datetime.datetime(2024, 4, 2, 12, 3, 44),
#  'dnssec': ['unsigned', 'Unsigned'],
#  'domain_name': 'AUGOVSERVICE-LOGIN.COM',
#  'emails': ['abuse-contact@publicdomainregistry.com', 'colinaalcorn@gmail.com'],
#  'expiration_date': datetime.datetime(2025, 4, 2, 12, 3, 44),
#  'name': 'Colin Alcorn',
#  'name_servers': ['ULLIS.NS.CLOUDFLARE.COM',
#                   'VERN.NS.CLOUDFLARE.COM',
#                   'ullis.ns.cloudflare.com',
#                   'vern.ns.cloudflare.com'],
#  'org': 'private person',
#  'referral_url': None,
#  'registrant_postal_code': '6280',
#  'registrar': 'PDR Ltd. d/b/a PublicDomainRegistry.com',
#  'state': 'Western Australia',
#  'status': 'clientTransferProhibited '
#            'https://icann.org/epp#clientTransferProhibited',
#  'updated_date': [datetime.datetime(2024, 4, 2, 12, 3, 44),
#                   datetime.datetime(2024, 4, 2, 12, 3, 46)],
#  'whois_server': 'whois.publicdomainregistry.com'}
# Looking up: logintolink.site
# {'address': 'Kalkofnsvegur 2',
#  'city': 'Reykjavik',
#  'country': 'IS',
#  'creation_date': datetime.datetime(2024, 4, 1, 15, 50, 28),
#  'dnssec': 'unsigned',
#  'domain_name': ['LOGINTOLINK.SITE', 'logintolink.site'],
#  'emails': ['abuse@namecheap.com',
#             '2ca7a43fc6f8479ba6927af6d107cc42.protect@withheldforprivacy.com'],
#  'expiration_date': datetime.datetime(2025, 4, 1, 15, 50, 28),
#  'name': 'Redacted for Privacy',
#  'name_servers': ['DNS1.REGISTRAR-SERVERS.COM',
#                   'DNS2.REGISTRAR-SERVERS.COM',
#                   'dns1.registrar-servers.com',
#                   'dns2.registrar-servers.com'],
#  'org': 'Privacy service provided by Withheld for Privacy ehf',
#  'registrant_postal_code': '101',
#  'registrar': 'NAMECHEAP INC',
#  'state': 'Capital Region',
#  'status': ['serverHold https://icann.org/epp#serverHold',
#             'serverTransferProhibited '
#             'https://icann.org/epp#serverTransferProhibited',
#             'clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited',
#             'addPeriod https://icann.org/epp#addPeriod'],
#  'updated_date': [datetime.datetime(2024, 4, 2, 6, 31, 34),
#                   datetime.datetime(1, 1, 1, 0, 0)],
#  'whois_server': 'whois.namecheap.com'}
# Looking up: goceng99login.com
# {'address': '1928 E. Highland Ave. Ste F104 PMB# 255',
#  'city': 'Phoenix',
#  'country': 'US',
#  'creation_date': [datetime.datetime(2024, 4, 4, 9, 19, 41),
#                    datetime.datetime(2024, 4, 4, 7, 0)],
#  'dnssec': 'unsigned',
#  'domain_name': ['GOCENG99LOGIN.COM', 'goceng99login.com'],
#  'emails': ['abuse@namesilo.com',
#             'pw-e815e44c7661e41929cb757be05ffd16@privacyguardian.org'],
#  'expiration_date': [datetime.datetime(2025, 4, 4, 9, 19, 41),
#                      datetime.datetime(2025, 4, 4, 7, 0)],
#  'name': 'REDACTED FOR PRIVACY',
#  'name_servers': ['NS1.DNSOWL.COM', 'NS2.DNSOWL.COM', 'NS3.DNSOWL.COM'],
#  'org': 'PrivacyGuardian.org llc',
#  'referral_url': None,
#  'registrant_postal_code': '85016',
#  'registrar': 'NameSilo, LLC',
#  'state': 'AZ',
#  'status': ['clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited',
#             'clientTransferProhibited '
#             'https://www.icann.org/epp#clientTransferProhibited'],
#  'updated_date': [datetime.datetime(2024, 4, 4, 9, 19, 41),
#                   datetime.datetime(2024, 4, 4, 7, 0)],
#  'whois_server': 'whois.namesilo.com'}
# Looking up: warkop77login.com
# {'address': '1928 E. Highland Ave. Ste F104 PMB# 255',
#  'city': 'Phoenix',
#  'country': 'US',
#  'creation_date': [datetime.datetime(2024, 4, 2, 7, 45, 43),
#                    datetime.datetime(2024, 4, 2, 7, 0)],
#  'dnssec': 'unsigned',
#  'domain_name': ['WARKOP77LOGIN.COM', 'warkop77login.com'],
#  'emails': ['abuse@namesilo.com',
#             'pw-2bda63fb7583d2bd27df8d4648abddf7@privacyguardian.org'],
#  'expiration_date': [datetime.datetime(2025, 4, 2, 7, 45, 43),
#                      datetime.datetime(2025, 4, 2, 7, 0)],
#  'name': 'REDACTED FOR PRIVACY',
#  'name_servers': ['NS1.ULTAHOST.MOBI', 'NS2.ULTAHOST.MOBI'],
#  'org': 'PrivacyGuardian.org llc',
#  'referral_url': None,
#  'registrant_postal_code': '85016',
#  'registrar': 'NameSilo, LLC',
#  'state': 'AZ',
#  'status': ['clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited',
#             'clientTransferProhibited '
#             'https://www.icann.org/epp#clientTransferProhibited'],
#  'updated_date': [datetime.datetime(2024, 4, 9, 10, 53, 5),
#                   datetime.datetime(2024, 4, 9, 7, 0)],
#  'whois_server': 'whois.namesilo.com'}
# Looking up: loginpersik4d.info
# {'address': 'REDACTED FOR PRIVACY',
#  'city': 'REDACTED FOR PRIVACY',
#  'country': 'US',
#  'creation_date': datetime.datetime(2024, 4, 2, 5, 36, 6),
#  'domain_name': 'loginpersik4d.info',
#  'emails': 'abuse@godaddy.com',
#  'expiration_date': datetime.datetime(2025, 4, 2, 5, 36, 6),
#  'name': 'REDACTED FOR PRIVACY',
#  'name_servers': ['ns39.domaincontrol.com', 'ns40.domaincontrol.com'],
#  'org': 'Domains By Proxy, LLC',
#  'referral_url': None,
#  'registrant_postal_code': 'REDACTED FOR PRIVACY',
#  'registrar': 'GoDaddy.com, LLC',
#  'state': 'Arizona',
#  'status': ['clientDeleteProhibited '
#             'https://icann.org/epp#clientDeleteProhibited',
#             'clientRenewProhibited https://icann.org/epp#clientRenewProhibited',
#             'clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited',
#             'clientUpdateProhibited '
#             'https://icann.org/epp#clientUpdateProhibited'],
#  'updated_date': datetime.datetime(2024, 4, 7, 5, 36, 39),
#  'whois_server': 'whois.godaddy.com/'}
# Looking up: tower88login.org
# {'address': 'REDACTED FOR PRIVACY',
#  'city': 'REDACTED FOR PRIVACY',
#  'country': 'US',
#  'creation_date': datetime.datetime(2024, 4, 6, 20, 2, 34),
#  'dnssec': 'unsigned',
#  'domain_name': 'tower88login.org',
#  'emails': 'abuse@namesilo.com',
#  'expiration_date': datetime.datetime(2025, 4, 6, 20, 2, 34),
#  'name': 'REDACTED FOR PRIVACY',
#  'name_servers': ['ns1.dnsowl.com', 'ns2.dnsowl.com', 'ns3.dnsowl.com'],
#  'org': 'PrivacyGuardian.org llc',
#  'referral_url': None,
#  'registrant_postal_code': 'REDACTED FOR PRIVACY',
#  'registrar': 'Namesilo, LLC',
#  'state': 'AZ',
#  'status': ['clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited',
#             'addPeriod https://icann.org/epp#addPeriod'],
#  'updated_date': datetime.datetime(2024, 4, 6, 20, 11, 6),
#  'whois_server': 'http://whois.namesilo.com'}
# Looking up: awan88login.com
# {'address': '1928 E. Highland Ave. Ste F104 PMB# 255',
#  'city': 'Phoenix',
#  'country': 'US',
#  'creation_date': [datetime.datetime(2024, 3, 30, 7, 9, 39),
#                    datetime.datetime(2024, 3, 30, 7, 0)],
#  'dnssec': 'unsigned',
#  'domain_name': ['AWAN88LOGIN.COM', 'awan88login.com'],
#  'emails': ['abuse@namesilo.com',
#             'pw-cb2c7836baf3553400516db180079525@privacyguardian.org'],
#  'expiration_date': [datetime.datetime(2025, 3, 30, 7, 9, 39),
#                      datetime.datetime(2025, 3, 30, 7, 0)],
#  'name': 'REDACTED FOR PRIVACY',
#  'name_servers': ['NS1.ULTAHOST.COM',
#                   'NS2.ULTAHOST.COM',
#                   'NS3.ULTAHOST.COM',
#                   'NS4.ULTAHOST.COM'],
#  'org': 'PrivacyGuardian.org llc',
#  'referral_url': None,
#  'registrant_postal_code': '85016',
#  'registrar': 'NameSilo, LLC',
#  'state': 'AZ',
#  'status': ['clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited',
#             'clientTransferProhibited '
#             'https://www.icann.org/epp#clientTransferProhibited'],
#  'updated_date': [datetime.datetime(2024, 3, 31, 7, 29, 47),
#                   datetime.datetime(2024, 3, 31, 7, 0)],
#  'whois_server': 'whois.namesilo.com'}
# Looking up: paypalcreidt.com
# {'address': 'REDACTED FOR PRIVACY',
#  'city': 'REDACTED FOR PRIVACY',
#  'country': 'CN',
#  'creation_date': [datetime.datetime(2023, 3, 28, 10, 46, 54),
#                    datetime.datetime(2023, 3, 28, 10, 46, 51)],
#  'dnssec': 'unsigned',
#  'domain_name': ['PAYPALCREIDT.COM', 'paypalcreidt.com'],
#  'emails': 'supervision@xinnet.com',
#  'expiration_date': [datetime.datetime(2025, 3, 28, 10, 46, 54),
#                      datetime.datetime(2024, 3, 28, 10, 46, 51)],
#  'name': 'REDACTED FOR PRIVACY',
#  'name_servers': ['DNS10.EXPIRENOTIFICATION.COM',
#                   'DNS9.EXPIRENOTIFICATION.COM',
#                   'ns1.parkingcrew.net',
#                   'ns2.parkingcrew.net'],
#  'org': 'REDACTED FOR PRIVACY',
#  'referral_url': None,
#  'registrant_postal_code': 'REDACTED FOR PRIVACY',
#  'registrar': 'Xin Net Technology Corporation',
#  'state': 'BJ',
#  'status': ['ok https://icann.org/epp#ok', 'ok https://www.icann.org/epp#ok'],
#  'updated_date': [datetime.datetime(2024, 4, 1, 16, 1, 26),
#                   datetime.datetime(2023, 3, 28, 10, 46, 51)],
#  'whois_server': 'whois.paycenter.com.cn'}
# Looking up: nix777login.net
# {'address': None,
#  'city': None,
#  'country': None,
#  'creation_date': datetime.datetime(2024, 4, 1, 5, 28),
#  'dnssec': 'unsigned',
#  'domain_name': 'NIX777LOGIN.NET',
#  'emails': 'abuse@namesilo.com',
#  'expiration_date': datetime.datetime(2025, 4, 1, 5, 28),
#  'name': None,
#  'name_servers': ['NS1.ULTAHOST.LAT', 'NS2.ULTAHOST.LAT'],
#  'org': None,
#  'referral_url': None,
#  'registrant_postal_code': None,
#  'registrar': 'NameSilo, LLC',
#  'state': None,
#  'status': 'clientTransferProhibited '
#            'https://icann.org/epp#clientTransferProhibited',
#  'updated_date': datetime.datetime(2024, 4, 9, 6, 25, 22),
#  'whois_server': 'whois.namesilo.com'}
# Looking up: ssoidrajasthanlogin.com
# {'address': 'Kalkofnsvegur 2',
#  'city': 'Reykjavik',
#  'country': 'IS',
#  'creation_date': datetime.datetime(2024, 4, 7, 1, 25, 23),
#  'dnssec': 'unsigned',
#  'domain_name': ['SSOIDRAJASTHANLOGIN.COM', 'ssoidrajasthanlogin.com'],
#  'emails': ['abuse@namecheap.com',
#             'a25755167cc0407f9b24360cddf694b1.protect@withheldforprivacy.com'],
#  'expiration_date': datetime.datetime(2025, 4, 7, 1, 25, 23),
#  'name': 'Redacted for Privacy',
#  'name_servers': ['DNS1.REGISTRAR-SERVERS.COM',
#                   'DNS2.REGISTRAR-SERVERS.COM',
#                   'dns1.registrar-servers.com',
#                   'dns2.registrar-servers.com'],
#  'org': 'Privacy service provided by Withheld for Privacy ehf',
#  'referral_url': None,
#  'registrant_postal_code': '101',
#  'registrar': 'NAMECHEAP INC',
#  'state': 'Capital Region',
#  'status': ['clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited',
#             'addPeriod https://icann.org/epp#addPeriod'],
#  'updated_date': [datetime.datetime(2024, 4, 7, 1, 25, 26),
#                   datetime.datetime(1, 1, 1, 0, 0)],
#  'whois_server': 'whois.namecheap.com'}
# Looking up: ketua4dlogin.org
# {'address': ['REDACTED FOR PRIVACY', 'Kalkofnsvegur 2'],
#  'city': ['REDACTED FOR PRIVACY', 'Reykjavik'],
#  'country': 'IS',
#  'creation_date': [datetime.datetime(2024, 3, 31, 7, 57, 41),
#                    datetime.datetime(2024, 3, 31, 7, 57, 41, 930000)],
#  'dnssec': 'unsigned',
#  'domain_name': 'ketua4dlogin.org',
#  'emails': ['abuse@namecheap.com',
#             'ca4d71ce6e8741cca6651f1b7bf42785.protect@withheldforprivacy.com'],
#  'expiration_date': [datetime.datetime(2025, 3, 31, 7, 57, 41),
#                      datetime.datetime(2025, 3, 31, 7, 57, 41, 930000)],
#  'name': ['REDACTED FOR PRIVACY', 'Redacted for Privacy'],
#  'name_servers': ['ns1.ultahost.com',
#                   'ns2.ultahost.com',
#                   'ns3.ultahost.com',
#                   'ns4.ultahost.com'],
#  'org': 'Privacy service provided by Withheld for Privacy ehf',
#  'referral_url': None,
#  'registrant_postal_code': ['REDACTED FOR PRIVACY', '101'],
#  'registrar': 'NAMECHEAP INC',
#  'state': 'Capital Region',
#  'status': 'clientTransferProhibited '
#            'https://icann.org/epp#clientTransferProhibited',
#  'updated_date': [datetime.datetime(2024, 4, 5, 7, 57, 49),
#                   datetime.datetime(1, 1, 1, 0, 0)],
#  'whois_server': 'whois.namecheap.com'}
# Looking up: paycore-logint9.shop
# {'address': None,
#  'city': None,
#  'country': 'US',
#  'creation_date': datetime.datetime(2024, 4, 2, 12, 24, 10),
#  'dnssec': 'unsigned',
#  'domain_name': 'PAYCORE-LOGINT9.SHOP',
#  'emails': 'abuse-contact@sav.com',
#  'expiration_date': datetime.datetime(2025, 4, 2, 23, 59, 59),
#  'name': None,
#  'name_servers': ['NITIN.NS.CLOUDFLARE.COM', 'STEVIE.NS.CLOUDFLARE.COM'],
#  'org': None,
#  'referral_url': None,
#  'registrant_postal_code': None,
#  'registrar': 'Sav.com, LLC',
#  'state': 'IL',
#  'status': 'clientTransferProhibited '
#            'https://icann.org/epp#clientTransferProhibited',
#  'updated_date': datetime.datetime(2024, 4, 2, 13, 49, 58),
#  'whois_server': 'https://whois.virtualcloud.co/'}
# Looking up: login-gov-help.org
# {'address': 'REDACTED FOR PRIVACY',
#  'city': 'REDACTED FOR PRIVACY',
#  'country': 'US',
#  'creation_date': datetime.datetime(2024, 3, 30, 22, 57, 31),
#  'dnssec': 'unsigned',
#  'domain_name': 'login-gov-help.org',
#  'emails': 'abuse@namesilo.com',
#  'expiration_date': datetime.datetime(2025, 3, 30, 22, 57, 31),
#  'name': 'REDACTED FOR PRIVACY',
#  'name_servers': ['colette.ns.cloudflare.com', 'ganz.ns.cloudflare.com'],
#  'org': 'PrivacyGuardian.org llc',
#  'referral_url': None,
#  'registrant_postal_code': 'REDACTED FOR PRIVACY',
#  'registrar': 'Namesilo, LLC',
#  'state': 'AZ',
#  'status': 'clientTransferProhibited '
#            'https://icann.org/epp#clientTransferProhibited',
#  'updated_date': datetime.datetime(2024, 4, 4, 22, 57, 54),
#  'whois_server': 'http://whois.namesilo.com'}
# Looking up: tiplogin.com
# {'address': 'Kalkofnsvegur 2',
#  'city': 'Reykjavik',
#  'country': 'IS',
#  'creation_date': datetime.datetime(2024, 3, 29, 6, 37, 36),
#  'dnssec': 'unsigned',
#  'domain_name': ['TIPLOGIN.COM', 'tiplogin.com'],
#  'emails': ['abuse@namecheap.com',
#             '5591753bb2d34f09bdf1662a9c459005.protect@withheldforprivacy.com'],
#  'expiration_date': datetime.datetime(2025, 3, 29, 6, 37, 36),
#  'name': 'Redacted for Privacy',
#  'name_servers': ['DAMIAN.NS.CLOUDFLARE.COM',
#                   'SAMARA.NS.CLOUDFLARE.COM',
#                   'damian.ns.cloudflare.com',
#                   'samara.ns.cloudflare.com'],
#  'org': 'Privacy service provided by Withheld for Privacy ehf',
#  'referral_url': None,
#  'registrant_postal_code': '101',
#  'registrar': 'NAMECHEAP INC',
#  'state': 'Capital Region',
#  'status': 'clientTransferProhibited '
#            'https://icann.org/epp#clientTransferProhibited',
#  'updated_date': [datetime.datetime(2024, 3, 29, 7, 54, 48),
#                   datetime.datetime(1, 1, 1, 0, 0)],
#  'whois_server': 'whois.namecheap.com'}
# Looking up: bandar69login.co
# {'address': ['REDACTED FOR PRIVACY', 'DomainsByProxy.com', '2155 E Warner Rd'],
#  'city': ['REDACTED FOR PRIVACY', 'Tempe'],
#  'country': 'US',
#  'creation_date': datetime.datetime(2024, 3, 22, 11, 24, 2),
#  'dnssec': 'unsigned',
#  'domain_name': 'bandar69login.co',
#  'emails': 'abuse@godaddy.com',
#  'expiration_date': datetime.datetime(2025, 3, 22, 11, 24, 2),
#  'name': ['REDACTED FOR PRIVACY', 'Registration Private'],
#  'name_servers': ['kenia.ns.cloudflare.com',
#                   'kellen.ns.cloudflare.com',
#                   'KELLEN.NS.CLOUDFLARE.COM',
#                   'KENIA.NS.CLOUDFLARE.COM'],
#  'org': 'Domains By Proxy, LLC',
#  'referral_url': None,
#  'registrant_postal_code': ['REDACTED FOR PRIVACY', '85284'],
#  'registrar': 'GoDaddy.com, LLC',
#  'state': 'Arizona',
#  'status': ['clientDeleteProhibited '
#             'https://icann.org/epp#clientDeleteProhibited',
#             'clientRenewProhibited https://icann.org/epp#clientRenewProhibited',
#             'clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited',
#             'clientUpdateProhibited '
#             'https://icann.org/epp#clientUpdateProhibited',
#             'serverTransferProhibited '
#             'https://icann.org/epp#serverTransferProhibited'],
#  'updated_date': [datetime.datetime(2024, 3, 29, 4, 50, 45),
#                   datetime.datetime(2024, 3, 22, 11, 24, 2)],
#  'whois_server': 'whois.godaddy.com'}
# Looking up: kingslot777login.bet
# {'address': ['REDACTED FOR PRIVACY', 'PO Box 701'],
#  'city': ['REDACTED FOR PRIVACY', 'San Mateo'],
#  'country': 'US',
#  'creation_date': datetime.datetime(2024, 3, 31, 7, 52),
#  'dnssec': 'unsigned',
#  'domain_name': ['kingslot777login.bet', 'KINGSLOT777LOGIN.BET'],
#  'emails': 'abuse@dynadot.com',
#  'expiration_date': datetime.datetime(2025, 3, 31, 7, 52),
#  'name': 'REDACTED FOR PRIVACY',
#  'name_servers': ['ns1.dyna-ns.net', 'ns2.dyna-ns.net'],
#  'org': 'Super Privacy Service LTD c/o Dynadot',
#  'referral_url': None,
#  'registrant_postal_code': ['REDACTED FOR PRIVACY', '94401'],
#  'registrar': 'DYNADOT LLC',
#  'state': 'California',
#  'status': 'clientTransferProhibited '
#            'https://icann.org/epp#clientTransferProhibited',
#  'updated_date': [datetime.datetime(2024, 4, 5, 7, 52, 14),
#                   datetime.datetime(2024, 3, 31, 7, 52, 17)],
#  'whois_server': 'whois.dynadot.com'}
# Looking up: cuan888login.com
# {'address': '1928 E. Highland Ave. Ste F104 PMB# 255',
#  'city': 'Phoenix',
#  'country': 'US',
#  'creation_date': [datetime.datetime(2024, 4, 6, 10, 22, 20),
#                    datetime.datetime(2024, 4, 6, 7, 0)],
#  'dnssec': 'unsigned',
#  'domain_name': ['CUAN888LOGIN.COM', 'cuan888login.com'],
#  'emails': ['abuse@namesilo.com',
#             'pw-2ddb1d7b101ee932887467d1268c66b1@privacyguardian.org'],
#  'expiration_date': [datetime.datetime(2025, 4, 6, 10, 22, 20),
#                      datetime.datetime(2025, 4, 6, 7, 0)],
#  'name': 'REDACTED FOR PRIVACY',
#  'name_servers': ['NS1.DNSOWL.COM', 'NS2.DNSOWL.COM', 'NS3.DNSOWL.COM'],
#  'org': 'PrivacyGuardian.org llc',
#  'referral_url': None,
#  'registrant_postal_code': '85016',
#  'registrar': 'NameSilo, LLC',
#  'state': 'AZ',
#  'status': ['clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited',
#             'clientTransferProhibited '
#             'https://www.icann.org/epp#clientTransferProhibited'],
#  'updated_date': [datetime.datetime(2024, 4, 6, 10, 22, 21),
#                   datetime.datetime(2024, 4, 6, 7, 0)],
#  'whois_server': 'whois.namesilo.com'}
# Looking up: slot633login.com
# {'address': None,
#  'city': None,
#  'country': None,
#  'creation_date': datetime.datetime(2024, 4, 6, 5, 22, 49),
#  'dnssec': 'unsigned',
#  'domain_name': 'SLOT633LOGIN.COM',
#  'emails': 'abuse@namesilo.com',
#  'expiration_date': datetime.datetime(2025, 4, 6, 5, 22, 49),
#  'name': None,
#  'name_servers': ['NS1.A2HOSTING.COM',
#                   'NS2.A2HOSTING.COM',
#                   'NS3.A2HOSTING.COM',
#                   'NS4.A2HOSTING.COM'],
#  'org': None,
#  'referral_url': None,
#  'registrant_postal_code': None,
#  'registrar': 'NameSilo, LLC',
#  'state': None,
#  'status': 'clientTransferProhibited '
#            'https://icann.org/epp#clientTransferProhibited',
#  'updated_date': datetime.datetime(2024, 4, 6, 6, 7, 46),
#  'whois_server': 'whois.namesilo.com'}
# Looking up: kera138login.net
# {'address': '1928 E. Highland Ave. Ste F104 PMB# 255',
#  'city': 'Phoenix',
#  'country': 'US',
#  'creation_date': [datetime.datetime(2024, 4, 5, 9, 27, 19),
#                    datetime.datetime(2024, 4, 5, 7, 0)],
#  'dnssec': 'unsigned',
#  'domain_name': ['KERA138LOGIN.NET', 'kera138login.net'],
#  'emails': ['abuse@namesilo.com',
#             'pw-d73c892e701e277f25c5cc209d0689cf@privacyguardian.org'],
#  'expiration_date': [datetime.datetime(2025, 4, 5, 9, 27, 19),
#                      datetime.datetime(2025, 4, 5, 7, 0)],
#  'name': 'REDACTED FOR PRIVACY',
#  'name_servers': ['NS1.DNSOWL.COM', 'NS2.DNSOWL.COM', 'NS3.DNSOWL.COM'],
#  'org': 'PrivacyGuardian.org llc',
#  'referral_url': None,
#  'registrant_postal_code': '85016',
#  'registrar': 'NameSilo, LLC',
#  'state': 'AZ',
#  'status': ['clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited',
#             'clientTransferProhibited '
#             'https://www.icann.org/epp#clientTransferProhibited'],
#  'updated_date': [datetime.datetime(2024, 4, 5, 9, 27, 19),
#                   datetime.datetime(2024, 4, 5, 7, 0)],
#  'whois_server': 'whois.namesilo.com'}
# Looking up: skipton-login.com
# {'address': None,
#  'city': None,
#  'country': 'US',
#  'creation_date': [datetime.datetime(2024, 4, 5, 1, 21, 16),
#                    datetime.datetime(2024, 4, 5, 1, 21, 31)],
#  'dnssec': 'unsigned',
#  'domain_name': ['SKIPTON-LOGIN.COM', 'skipton-login.com'],
#  'emails': 'abuse@nicenic.net',
#  'expiration_date': datetime.datetime(2025, 4, 5, 1, 21, 16),
#  'name': None,
#  'name_servers': ['NS1.REG-NET79.COM', 'NS2.REG-NET79.COM'],
#  'org': 'BentleeHoster',
#  'referral_url': None,
#  'registrant_postal_code': None,
#  'registrar': 'NICENIC INTERNATIONAL GROUP CO., LIMITED',
#  'state': 'CA',
#  'status': ['clientDeleteProhibited '
#             'https://icann.org/epp#clientDeleteProhibited',
#             'clientTransferProhibited '
#             'https://icann.org/epp#clientTransferProhibited'],
#  'updated_date': [datetime.datetime(2024, 4, 5, 1, 21, 17),
#                   datetime.datetime(2024, 4, 5, 1, 21, 31)],
#  'whois_server': 'whois.nicenic.net'}
# Looking up: harta777login.com
# {'address': None,
#  'city': None,
#  'country': None,
#  'creation_date': datetime.datetime(2024, 4, 2, 7, 45, 53),
#  'dnssec': 'unsigned',
#  'domain_name': 'HARTA777LOGIN.COM',
#  'emails': 'abuse@namesilo.com',
#  'expiration_date': datetime.datetime(2025, 4, 2, 7, 45, 53),
#  'name': None,
#  'name_servers': ['NS1.DNSOWL.COM', 'NS2.DNSOWL.COM', 'NS3.DNSOWL.COM'],
#  'org': None,
#  'referral_url': None,
#  'registrant_postal_code': None,
#  'registrar': 'NameSilo, LLC',
#  'state': None,
#  'status': 'clientTransferProhibited '
#            'https://icann.org/epp#clientTransferProhibited',
#  'updated_date': datetime.datetime(2024, 4, 2, 7, 45, 53),
#  'whois_server': 'whois.namesilo.com'}
# Looking up: indonesialogin30.com
# {'address': 'PO Box 701',
#  'city': 'San Mateo',
#  'country': 'US',
#  'creation_date': datetime.datetime(2024, 3, 31, 10, 3, 52),
#  'dnssec': 'unsigned',
#  'domain_name': 'INDONESIALOGIN30.COM',
#  'emails': 'abuse@dynadot.com',
#  'expiration_date': datetime.datetime(2025, 3, 31, 10, 3, 52),
#  'name': 'REDACTED FOR PRIVACY',
#  'name_servers': ['DARL.NS.CLOUDFLARE.COM',
#                   'ROSA.NS.CLOUDFLARE.COM',
#                   'darl.ns.cloudflare.com',
#                   'rosa.ns.cloudflare.com'],
#  'org': 'Super Privacy Service LTD c/o Dynadot',
#  'referral_url': None,
#  'registrant_postal_code': '94401',
#  'registrar': 'DYNADOT LLC',
#  'state': 'California',
#  'status': 'clientTransferProhibited '
#            'https://icann.org/epp#clientTransferProhibited',
#  'updated_date': datetime.datetime(2024, 4, 5, 10, 56, 19),
#  'whois_server': 'whois.dynadot.com'}
# Looking up: ncbupdatelogin.org
# ---------------------------------------------------------------------------
# PywhoisError                              Traceback (most recent call last)
# Cell In[6], line 11
#       9 print('Looking up: {}'.format(domain))
#      10 domains.append(domain)
# ---> 11 w = whois.whois(domain)
#      12 pprint(w)
#      13 creation_dates.append(w.get('creation_date',None))
#
# File /opt/homebrew/lib/python3.12/site-packages/whois/__init__.py:47, in whois(url, command, flags, executable, inc_raw, quiet)
#      45     nic_client = NICClient()
#      46     text = nic_client.whois_lookup(None, domain.encode("idna"), flags, quiet=quiet)
# ---> 47 entry = WhoisEntry.load(domain, text)
#      48 if inc_raw:
#      49     entry["raw"] = text
#
# File /opt/homebrew/lib/python3.12/site-packages/whois/parser.py:192, in WhoisEntry.load(domain, text)
#     190     return WhoisNet(domain, text)
#     191 elif domain.endswith(".org"):
# --> 192     return WhoisOrg(domain, text)
#     193 elif domain.endswith(".name"):
#     194     return WhoisName(domain, text)
#
# File /opt/homebrew/lib/python3.12/site-packages/whois/parser.py:518, in WhoisOrg.__init__(self, domain, text)
#     514 def __init__(self, domain, text):
#     515     if text.strip().startswith("NOT FOUND") or text.strip().startswith(
#     516         "Domain not found"
#     517     ):
# --> 518         raise PywhoisError(text)
#     519     else:
#     520         WhoisEntry.__init__(self, domain, text)
#
# PywhoisError: Domain not found.
# >>> Last update of WHOIS database: 2024-04-09T16:36:37Z <<<
#
# Terms of Use: Access to Public Interest Registry WHOIS information is provided to assist persons in determining the contents of a domain name registration record in the Public Interest Registry registry database. The data in this record is provided by Public Interest Registry for informational purposes only, and Public Interest Registry does not guarantee its accuracy. This service is intended only for query-based access. You agree that you will use this data only for lawful purposes and that, under no circumstances will you use this data to (a) allow, enable, or otherwise support the transmission by e-mail, telephone, or facsimile of mass unsolicited, commercial advertising or solicitations to entities other than the data recipient's own existing customers; or (b) enable high volume, automated, electronic processes that send queries or data to the systems of Registry Operator, a Registrar, or Identity Digital except as reasonably necessary to register domain names or modify existing registrations. All rights reserved. Public Interest Registry reserves the right to modify these terms at any time. By submitting this query, you agree to abide by this policy.  The Registrar of Record identified in this output may have an RDDS service that can be queried for additional information on how to contact the Registrant, Admin, or Tech contact of the queried domain name.

# %% [markdown]
# #### Convert domain info into a pandas data frame and fix some formatting

# %%
domain_info=(list(zip(domains, creation_dates,expiration_dates,updated_dates,name_servers)))
df = pd.DataFrame(domain_info,columns=['domain','Creation_Date','Expiration_Date','Updated_Date','Name_Servers'])
df['creation_date']=df["Creation_Date"].str[0]
df['expiration_date']=df["Expiration_Date"].str[0]
df['updated_date']=df["Updated_Date"].str[0]

df['first_name_server']=df["Name_Servers"].str[0]
df['second_name_server']=df["Name_Servers"].str[1]
print(df)
# Out:
#                                 domain  \
# 0                          login-eu.pw
# 1                    microsoft365.buzz
# 2                  bidadari99login.net
# 3                klikbet77newlogin.xyz
# 4                 microsoftautogen.net
# 5                hollywoodlogin.africa
# 6          employeexpress-loginp5.shop
# 7                     tango4dlogin.net
# 8           bitmart-login-official.com
# 9                  bet777slotlogin.com
# 10  enviromaticsystems-onmicrosoft.com
# 11                      hbo77login.com
# 12              augovservice-login.com
# 13                    logintolink.site
# 14                   goceng99login.com
# 15                   warkop77login.com
# 16                  loginpersik4d.info
# 17                    tower88login.org
# 18                     awan88login.com
# 19                    paypalcreidt.com
# 20                     nix777login.net
# 21             ssoidrajasthanlogin.com
# 22                    ketua4dlogin.org
# 23                paycore-logint9.shop
# 24                  login-gov-help.org
# 25                        tiplogin.com
# 26                    bandar69login.co
# 27                kingslot777login.bet
# 28                    cuan888login.com
# 29                    slot633login.com
# 30                    kera138login.net
# 31                   skipton-login.com
# 32                   harta777login.com
# 33                indonesialogin30.com
#
#                                         Creation_Date  \
# 0                                 2024-03-28 20:16:56
# 1          [2024-04-07 15:11:53, 2024-04-07 07:00:00]
# 2          [2024-04-03 10:18:48, 2024-04-03 07:00:00]
# 3                                 2024-04-06 09:02:21
# 4                                 2023-09-27 06:46:17
# 5                                 2024-03-29 22:56:47
# 6                                 2024-03-29 20:08:44
# 7          [2024-04-05 06:40:43, 2024-04-04 07:00:00]
# 8                                 2023-03-25 02:22:01
# 9                                 2024-04-03 03:49:28
# 10         [2024-04-03 12:12:03, 2024-04-03 07:12:03]
# 11         [2024-04-05 09:27:00, 2024-04-05 07:00:00]
# 12                                2024-04-02 12:03:44
# 13                                2024-04-01 15:50:28
# 14         [2024-04-04 09:19:41, 2024-04-04 07:00:00]
# 15         [2024-04-02 07:45:43, 2024-04-02 07:00:00]
# 16                                2024-04-02 05:36:06
# 17                                2024-04-06 20:02:34
# 18         [2024-03-30 07:09:39, 2024-03-30 07:00:00]
# 19         [2023-03-28 10:46:54, 2023-03-28 10:46:51]
# 20                                2024-04-01 05:28:00
# 21                                2024-04-07 01:25:23
# 22  [2024-03-31 07:57:41, 2024-03-31 07:57:41.930000]
# 23                                2024-04-02 12:24:10
# 24                                2024-03-30 22:57:31
# 25                                2024-03-29 06:37:36
# 26                                2024-03-22 11:24:02
# 27                                2024-03-31 07:52:00
# 28         [2024-04-06 10:22:20, 2024-04-06 07:00:00]
# 29                                2024-04-06 05:22:49
# 30         [2024-04-05 09:27:19, 2024-04-05 07:00:00]
# 31         [2024-04-05 01:21:16, 2024-04-05 01:21:31]
# 32                                2024-04-02 07:45:53
# 33                                2024-03-31 10:03:52
#
#                                       Expiration_Date  \
# 0                                 2025-03-28 23:59:59
# 1          [2025-04-07 15:11:53, 2025-04-07 07:00:00]
# 2          [2025-04-03 10:18:48, 2025-04-03 07:00:00]
# 3          [2025-04-06 23:59:59, 2025-04-06 09:02:21]
# 4                                 2024-09-27 06:46:17
# 5                                 2025-03-29 22:56:47
# 6                                 2025-03-29 23:59:59
# 7          [2025-04-05 06:40:43, 2025-04-04 07:00:00]
# 8          [2025-03-25 02:22:01, 2024-03-25 02:22:01]
# 9                                 2025-04-03 03:49:28
# 10         [2025-04-03 12:12:03, 2025-04-03 07:12:03]
# 11         [2025-04-05 09:27:00, 2025-04-05 07:00:00]
# 12                                2025-04-02 12:03:44
# 13                                2025-04-01 15:50:28
# 14         [2025-04-04 09:19:41, 2025-04-04 07:00:00]
# 15         [2025-04-02 07:45:43, 2025-04-02 07:00:00]
# 16                                2025-04-02 05:36:06
# 17                                2025-04-06 20:02:34
# 18         [2025-03-30 07:09:39, 2025-03-30 07:00:00]
# 19         [2025-03-28 10:46:54, 2024-03-28 10:46:51]
# 20                                2025-04-01 05:28:00
# 21                                2025-04-07 01:25:23
# 22  [2025-03-31 07:57:41, 2025-03-31 07:57:41.930000]
# 23                                2025-04-02 23:59:59
# 24                                2025-03-30 22:57:31
# 25                                2025-03-29 06:37:36
# 26                                2025-03-22 11:24:02
# 27                                2025-03-31 07:52:00
# 28         [2025-04-06 10:22:20, 2025-04-06 07:00:00]
# 29                                2025-04-06 05:22:49
# 30         [2025-04-05 09:27:19, 2025-04-05 07:00:00]
# 31                                2025-04-05 01:21:16
# 32                                2025-04-02 07:45:53
# 33                                2025-03-31 10:03:52
#
#                                          Updated_Date  \
# 0                                 2024-04-02 20:21:29
# 1          [2024-04-07 15:25:15, 2024-04-08 07:00:00]
# 2          [2024-04-03 10:18:48, 2024-04-03 07:00:00]
# 3          [2024-04-06 09:02:24, 0001-01-01 00:00:00]
# 4   [2024-04-03 23:45:02, 2024-04-03 23:45:02.904040]
# 5          [2024-03-30 21:41:30, 2024-03-30 22:41:33]
# 6                                 2024-03-29 20:51:04
# 7          [2024-04-05 06:40:43, 2024-04-05 07:00:00]
# 8                                 2024-03-29 06:57:46
# 9          [2024-04-03 04:03:18, 0001-01-01 00:00:00]
# 10         [2024-04-03 12:12:04, 2024-04-03 07:12:04]
# 11         [2024-04-05 09:27:00, 2024-04-05 07:00:00]
# 12         [2024-04-02 12:03:44, 2024-04-02 12:03:46]
# 13         [2024-04-02 06:31:34, 0001-01-01 00:00:00]
# 14         [2024-04-04 09:19:41, 2024-04-04 07:00:00]
# 15         [2024-04-09 10:53:05, 2024-04-09 07:00:00]
# 16                                2024-04-07 05:36:39
# 17                                2024-04-06 20:11:06
# 18         [2024-03-31 07:29:47, 2024-03-31 07:00:00]
# 19         [2024-04-01 16:01:26, 2023-03-28 10:46:51]
# 20                                2024-04-09 06:25:22
# 21         [2024-04-07 01:25:26, 0001-01-01 00:00:00]
# 22         [2024-04-05 07:57:49, 0001-01-01 00:00:00]
# 23                                2024-04-02 13:49:58
# 24                                2024-04-04 22:57:54
# 25         [2024-03-29 07:54:48, 0001-01-01 00:00:00]
# 26         [2024-03-29 04:50:45, 2024-03-22 11:24:02]
# 27         [2024-04-05 07:52:14, 2024-03-31 07:52:17]
# 28         [2024-04-06 10:22:21, 2024-04-06 07:00:00]
# 29                                2024-04-06 06:07:46
# 30         [2024-04-05 09:27:19, 2024-04-05 07:00:00]
# 31         [2024-04-05 01:21:17, 2024-04-05 01:21:31]
# 32                                2024-04-02 07:45:53
# 33                                2024-04-05 10:56:19
#
#                                          Name_Servers        creation_date  \
# 0   [NS2.BEGET.PRO, NS2.BEGET.COM, NS1.BEGET.PRO, ...                  NaN
# 1   [sean.ns.cloudflare.com, kira.ns.cloudflare.co...  2024-04-07 15:11:53
# 2    [NS1.DNSOWL.COM, NS2.DNSOWL.COM, NS3.DNSOWL.COM]  2024-04-03 10:18:48
# 3   [DNS1.NAMECHEAPHOSTING.COM, DNS2.NAMECHEAPHOST...                  NaN
# 4   [DNS1.P09.NSONE.NET, DNS2.P09.NSONE.NET, DNS3....                  NaN
# 5   [wren.ns.cloudflare.com, margo.ns.cloudflare.com]                  NaN
# 6   [CULLEN.NS.CLOUDFLARE.COM, LIA.NS.CLOUDFLARE.COM]                  NaN
# 7    [NS1.DNSOWL.COM, NS2.DNSOWL.COM, NS3.DNSOWL.COM]  2024-04-05 06:40:43
# 8   [NS1.RENEWYOURNAME.NET, NS2.RENEWYOURNAME.NET,...                  NaN
# 9   [BARBARA.NS.CLOUDFLARE.COM, LENNON.NS.CLOUDFLA...                  NaN
# 10  [NS1.BDM.MICROSOFTONLINE.COM, NS2.BDM.MICROSOF...  2024-04-03 12:12:03
# 11   [NS1.DNSOWL.COM, NS2.DNSOWL.COM, NS3.DNSOWL.COM]  2024-04-05 09:27:00
# 12  [ULLIS.NS.CLOUDFLARE.COM, VERN.NS.CLOUDFLARE.C...                  NaN
# 13  [DNS1.REGISTRAR-SERVERS.COM, DNS2.REGISTRAR-SE...                  NaN
# 14   [NS1.DNSOWL.COM, NS2.DNSOWL.COM, NS3.DNSOWL.COM]  2024-04-04 09:19:41
# 15             [NS1.ULTAHOST.MOBI, NS2.ULTAHOST.MOBI]  2024-04-02 07:45:43
# 16   [ns39.domaincontrol.com, ns40.domaincontrol.com]                  NaN
# 17   [ns1.dnsowl.com, ns2.dnsowl.com, ns3.dnsowl.com]                  NaN
# 18  [NS1.ULTAHOST.COM, NS2.ULTAHOST.COM, NS3.ULTAH...  2024-03-30 07:09:39
# 19  [DNS10.EXPIRENOTIFICATION.COM, DNS9.EXPIRENOTI...  2023-03-28 10:46:54
# 20               [NS1.ULTAHOST.LAT, NS2.ULTAHOST.LAT]                  NaN
# 21  [DNS1.REGISTRAR-SERVERS.COM, DNS2.REGISTRAR-SE...                  NaN
# 22  [ns1.ultahost.com, ns2.ultahost.com, ns3.ultah...  2024-03-31 07:57:41
# 23  [NITIN.NS.CLOUDFLARE.COM, STEVIE.NS.CLOUDFLARE...                  NaN
# 24  [colette.ns.cloudflare.com, ganz.ns.cloudflare...                  NaN
# 25  [DAMIAN.NS.CLOUDFLARE.COM, SAMARA.NS.CLOUDFLAR...                  NaN
# 26  [kenia.ns.cloudflare.com, kellen.ns.cloudflare...                  NaN
# 27                 [ns1.dyna-ns.net, ns2.dyna-ns.net]                  NaN
# 28   [NS1.DNSOWL.COM, NS2.DNSOWL.COM, NS3.DNSOWL.COM]  2024-04-06 10:22:20
# 29  [NS1.A2HOSTING.COM, NS2.A2HOSTING.COM, NS3.A2H...                  NaN
# 30   [NS1.DNSOWL.COM, NS2.DNSOWL.COM, NS3.DNSOWL.COM]  2024-04-05 09:27:19
# 31             [NS1.REG-NET79.COM, NS2.REG-NET79.COM]  2024-04-05 01:21:16
# 32   [NS1.DNSOWL.COM, NS2.DNSOWL.COM, NS3.DNSOWL.COM]                  NaN
# 33  [DARL.NS.CLOUDFLARE.COM, ROSA.NS.CLOUDFLARE.CO...                  NaN
#
#         expiration_date         updated_date             first_name_server  \
# 0                   NaN                  NaN                 NS2.BEGET.PRO
# 1   2025-04-07 15:11:53  2024-04-07 15:25:15        sean.ns.cloudflare.com
# 2   2025-04-03 10:18:48  2024-04-03 10:18:48                NS1.DNSOWL.COM
# 3   2025-04-06 23:59:59  2024-04-06 09:02:24     DNS1.NAMECHEAPHOSTING.COM
# 4                   NaN  2024-04-03 23:45:02            DNS1.P09.NSONE.NET
# 5                   NaN  2024-03-30 21:41:30        wren.ns.cloudflare.com
# 6                   NaN                  NaN      CULLEN.NS.CLOUDFLARE.COM
# 7   2025-04-05 06:40:43  2024-04-05 06:40:43                NS1.DNSOWL.COM
# 8   2025-03-25 02:22:01                  NaN         NS1.RENEWYOURNAME.NET
# 9                   NaN  2024-04-03 04:03:18     BARBARA.NS.CLOUDFLARE.COM
# 10  2025-04-03 12:12:03  2024-04-03 12:12:04   NS1.BDM.MICROSOFTONLINE.COM
# 11  2025-04-05 09:27:00  2024-04-05 09:27:00                NS1.DNSOWL.COM
# 12                  NaN  2024-04-02 12:03:44       ULLIS.NS.CLOUDFLARE.COM
# 13                  NaN  2024-04-02 06:31:34    DNS1.REGISTRAR-SERVERS.COM
# 14  2025-04-04 09:19:41  2024-04-04 09:19:41                NS1.DNSOWL.COM
# 15  2025-04-02 07:45:43  2024-04-09 10:53:05             NS1.ULTAHOST.MOBI
# 16                  NaN                  NaN        ns39.domaincontrol.com
# 17                  NaN                  NaN                ns1.dnsowl.com
# 18  2025-03-30 07:09:39  2024-03-31 07:29:47              NS1.ULTAHOST.COM
# 19  2025-03-28 10:46:54  2024-04-01 16:01:26  DNS10.EXPIRENOTIFICATION.COM
# 20                  NaN                  NaN              NS1.ULTAHOST.LAT
# 21                  NaN  2024-04-07 01:25:26    DNS1.REGISTRAR-SERVERS.COM
# 22  2025-03-31 07:57:41  2024-04-05 07:57:49              ns1.ultahost.com
# 23                  NaN                  NaN       NITIN.NS.CLOUDFLARE.COM
# 24                  NaN                  NaN     colette.ns.cloudflare.com
# 25                  NaN  2024-03-29 07:54:48      DAMIAN.NS.CLOUDFLARE.COM
# 26                  NaN  2024-03-29 04:50:45       kenia.ns.cloudflare.com
# 27                  NaN  2024-04-05 07:52:14               ns1.dyna-ns.net
# 28  2025-04-06 10:22:20  2024-04-06 10:22:21                NS1.DNSOWL.COM
# 29                  NaN                  NaN             NS1.A2HOSTING.COM
# 30  2025-04-05 09:27:19  2024-04-05 09:27:19                NS1.DNSOWL.COM
# 31                  NaN  2024-04-05 01:21:17             NS1.REG-NET79.COM
# 32                  NaN                  NaN                NS1.DNSOWL.COM
# 33                  NaN                  NaN        DARL.NS.CLOUDFLARE.COM
#
#              second_name_server
# 0                 NS2.BEGET.COM
# 1        kira.ns.cloudflare.com
# 2                NS2.DNSOWL.COM
# 3     DNS2.NAMECHEAPHOSTING.COM
# 4            DNS2.P09.NSONE.NET
# 5       margo.ns.cloudflare.com
# 6         LIA.NS.CLOUDFLARE.COM
# 7                NS2.DNSOWL.COM
# 8         NS2.RENEWYOURNAME.NET
# 9      LENNON.NS.CLOUDFLARE.COM
# 10  NS2.BDM.MICROSOFTONLINE.COM
# 11               NS2.DNSOWL.COM
# 12       VERN.NS.CLOUDFLARE.COM
# 13   DNS2.REGISTRAR-SERVERS.COM
# 14               NS2.DNSOWL.COM
# 15            NS2.ULTAHOST.MOBI
# 16       ns40.domaincontrol.com
# 17               ns2.dnsowl.com
# 18             NS2.ULTAHOST.COM
# 19  DNS9.EXPIRENOTIFICATION.COM
# 20             NS2.ULTAHOST.LAT
# 21   DNS2.REGISTRAR-SERVERS.COM
# 22             ns2.ultahost.com
# 23     STEVIE.NS.CLOUDFLARE.COM
# 24       ganz.ns.cloudflare.com
# 25     SAMARA.NS.CLOUDFLARE.COM
# 26     kellen.ns.cloudflare.com
# 27              ns2.dyna-ns.net
# 28               NS2.DNSOWL.COM
# 29            NS2.A2HOSTING.COM
# 30               NS2.DNSOWL.COM
# 31            NS2.REG-NET79.COM
# 32               NS2.DNSOWL.COM
# 33       ROSA.NS.CLOUDFLARE.COM

# %% [markdown]
# #### Extraxt the tlds from the domains

# %%
def extract_tld(domain):
    ext=extract(domain)
    return ext.suffix

# %%
df['domain'] = df['domain'].astype(str)
#try:
#    df['registered_domain']=df['domain'].apply(get_tld)
#except:
#    pass
df['domain_tld'] = df['domain'].apply(extract_tld)

#f['domain_tld']=extract_tld(df.domain)
print(df)
# Out:
#                                 domain  \
# 0                          login-eu.pw
# 1                    microsoft365.buzz
# 2                  bidadari99login.net
# 3                klikbet77newlogin.xyz
# 4                 microsoftautogen.net
# 5                hollywoodlogin.africa
# 6          employeexpress-loginp5.shop
# 7                     tango4dlogin.net
# 8           bitmart-login-official.com
# 9                  bet777slotlogin.com
# 10  enviromaticsystems-onmicrosoft.com
# 11                      hbo77login.com
# 12              augovservice-login.com
# 13                    logintolink.site
# 14                   goceng99login.com
# 15                   warkop77login.com
# 16                  loginpersik4d.info
# 17                    tower88login.org
# 18                     awan88login.com
# 19                    paypalcreidt.com
# 20                     nix777login.net
# 21             ssoidrajasthanlogin.com
# 22                    ketua4dlogin.org
# 23                paycore-logint9.shop
# 24                  login-gov-help.org
# 25                        tiplogin.com
# 26                    bandar69login.co
# 27                kingslot777login.bet
# 28                    cuan888login.com
# 29                    slot633login.com
# 30                    kera138login.net
# 31                   skipton-login.com
# 32                   harta777login.com
# 33                indonesialogin30.com
#
#                                         Creation_Date  \
# 0                                 2024-03-28 20:16:56
# 1          [2024-04-07 15:11:53, 2024-04-07 07:00:00]
# 2          [2024-04-03 10:18:48, 2024-04-03 07:00:00]
# 3                                 2024-04-06 09:02:21
# 4                                 2023-09-27 06:46:17
# 5                                 2024-03-29 22:56:47
# 6                                 2024-03-29 20:08:44
# 7          [2024-04-05 06:40:43, 2024-04-04 07:00:00]
# 8                                 2023-03-25 02:22:01
# 9                                 2024-04-03 03:49:28
# 10         [2024-04-03 12:12:03, 2024-04-03 07:12:03]
# 11         [2024-04-05 09:27:00, 2024-04-05 07:00:00]
# 12                                2024-04-02 12:03:44
# 13                                2024-04-01 15:50:28
# 14         [2024-04-04 09:19:41, 2024-04-04 07:00:00]
# 15         [2024-04-02 07:45:43, 2024-04-02 07:00:00]
# 16                                2024-04-02 05:36:06
# 17                                2024-04-06 20:02:34
# 18         [2024-03-30 07:09:39, 2024-03-30 07:00:00]
# 19         [2023-03-28 10:46:54, 2023-03-28 10:46:51]
# 20                                2024-04-01 05:28:00
# 21                                2024-04-07 01:25:23
# 22  [2024-03-31 07:57:41, 2024-03-31 07:57:41.930000]
# 23                                2024-04-02 12:24:10
# 24                                2024-03-30 22:57:31
# 25                                2024-03-29 06:37:36
# 26                                2024-03-22 11:24:02
# 27                                2024-03-31 07:52:00
# 28         [2024-04-06 10:22:20, 2024-04-06 07:00:00]
# 29                                2024-04-06 05:22:49
# 30         [2024-04-05 09:27:19, 2024-04-05 07:00:00]
# 31         [2024-04-05 01:21:16, 2024-04-05 01:21:31]
# 32                                2024-04-02 07:45:53
# 33                                2024-03-31 10:03:52
#
#                                       Expiration_Date  \
# 0                                 2025-03-28 23:59:59
# 1          [2025-04-07 15:11:53, 2025-04-07 07:00:00]
# 2          [2025-04-03 10:18:48, 2025-04-03 07:00:00]
# 3          [2025-04-06 23:59:59, 2025-04-06 09:02:21]
# 4                                 2024-09-27 06:46:17
# 5                                 2025-03-29 22:56:47
# 6                                 2025-03-29 23:59:59
# 7          [2025-04-05 06:40:43, 2025-04-04 07:00:00]
# 8          [2025-03-25 02:22:01, 2024-03-25 02:22:01]
# 9                                 2025-04-03 03:49:28
# 10         [2025-04-03 12:12:03, 2025-04-03 07:12:03]
# 11         [2025-04-05 09:27:00, 2025-04-05 07:00:00]
# 12                                2025-04-02 12:03:44
# 13                                2025-04-01 15:50:28
# 14         [2025-04-04 09:19:41, 2025-04-04 07:00:00]
# 15         [2025-04-02 07:45:43, 2025-04-02 07:00:00]
# 16                                2025-04-02 05:36:06
# 17                                2025-04-06 20:02:34
# 18         [2025-03-30 07:09:39, 2025-03-30 07:00:00]
# 19         [2025-03-28 10:46:54, 2024-03-28 10:46:51]
# 20                                2025-04-01 05:28:00
# 21                                2025-04-07 01:25:23
# 22  [2025-03-31 07:57:41, 2025-03-31 07:57:41.930000]
# 23                                2025-04-02 23:59:59
# 24                                2025-03-30 22:57:31
# 25                                2025-03-29 06:37:36
# 26                                2025-03-22 11:24:02
# 27                                2025-03-31 07:52:00
# 28         [2025-04-06 10:22:20, 2025-04-06 07:00:00]
# 29                                2025-04-06 05:22:49
# 30         [2025-04-05 09:27:19, 2025-04-05 07:00:00]
# 31                                2025-04-05 01:21:16
# 32                                2025-04-02 07:45:53
# 33                                2025-03-31 10:03:52
#
#                                          Updated_Date  \
# 0                                 2024-04-02 20:21:29
# 1          [2024-04-07 15:25:15, 2024-04-08 07:00:00]
# 2          [2024-04-03 10:18:48, 2024-04-03 07:00:00]
# 3          [2024-04-06 09:02:24, 0001-01-01 00:00:00]
# 4   [2024-04-03 23:45:02, 2024-04-03 23:45:02.904040]
# 5          [2024-03-30 21:41:30, 2024-03-30 22:41:33]
# 6                                 2024-03-29 20:51:04
# 7          [2024-04-05 06:40:43, 2024-04-05 07:00:00]
# 8                                 2024-03-29 06:57:46
# 9          [2024-04-03 04:03:18, 0001-01-01 00:00:00]
# 10         [2024-04-03 12:12:04, 2024-04-03 07:12:04]
# 11         [2024-04-05 09:27:00, 2024-04-05 07:00:00]
# 12         [2024-04-02 12:03:44, 2024-04-02 12:03:46]
# 13         [2024-04-02 06:31:34, 0001-01-01 00:00:00]
# 14         [2024-04-04 09:19:41, 2024-04-04 07:00:00]
# 15         [2024-04-09 10:53:05, 2024-04-09 07:00:00]
# 16                                2024-04-07 05:36:39
# 17                                2024-04-06 20:11:06
# 18         [2024-03-31 07:29:47, 2024-03-31 07:00:00]
# 19         [2024-04-01 16:01:26, 2023-03-28 10:46:51]
# 20                                2024-04-09 06:25:22
# 21         [2024-04-07 01:25:26, 0001-01-01 00:00:00]
# 22         [2024-04-05 07:57:49, 0001-01-01 00:00:00]
# 23                                2024-04-02 13:49:58
# 24                                2024-04-04 22:57:54
# 25         [2024-03-29 07:54:48, 0001-01-01 00:00:00]
# 26         [2024-03-29 04:50:45, 2024-03-22 11:24:02]
# 27         [2024-04-05 07:52:14, 2024-03-31 07:52:17]
# 28         [2024-04-06 10:22:21, 2024-04-06 07:00:00]
# 29                                2024-04-06 06:07:46
# 30         [2024-04-05 09:27:19, 2024-04-05 07:00:00]
# 31         [2024-04-05 01:21:17, 2024-04-05 01:21:31]
# 32                                2024-04-02 07:45:53
# 33                                2024-04-05 10:56:19
#
#                                          Name_Servers        creation_date  \
# 0   [NS2.BEGET.PRO, NS2.BEGET.COM, NS1.BEGET.PRO, ...                  NaN
# 1   [sean.ns.cloudflare.com, kira.ns.cloudflare.co...  2024-04-07 15:11:53
# 2    [NS1.DNSOWL.COM, NS2.DNSOWL.COM, NS3.DNSOWL.COM]  2024-04-03 10:18:48
# 3   [DNS1.NAMECHEAPHOSTING.COM, DNS2.NAMECHEAPHOST...                  NaN
# 4   [DNS1.P09.NSONE.NET, DNS2.P09.NSONE.NET, DNS3....                  NaN
# 5   [wren.ns.cloudflare.com, margo.ns.cloudflare.com]                  NaN
# 6   [CULLEN.NS.CLOUDFLARE.COM, LIA.NS.CLOUDFLARE.COM]                  NaN
# 7    [NS1.DNSOWL.COM, NS2.DNSOWL.COM, NS3.DNSOWL.COM]  2024-04-05 06:40:43
# 8   [NS1.RENEWYOURNAME.NET, NS2.RENEWYOURNAME.NET,...                  NaN
# 9   [BARBARA.NS.CLOUDFLARE.COM, LENNON.NS.CLOUDFLA...                  NaN
# 10  [NS1.BDM.MICROSOFTONLINE.COM, NS2.BDM.MICROSOF...  2024-04-03 12:12:03
# 11   [NS1.DNSOWL.COM, NS2.DNSOWL.COM, NS3.DNSOWL.COM]  2024-04-05 09:27:00
# 12  [ULLIS.NS.CLOUDFLARE.COM, VERN.NS.CLOUDFLARE.C...                  NaN
# 13  [DNS1.REGISTRAR-SERVERS.COM, DNS2.REGISTRAR-SE...                  NaN
# 14   [NS1.DNSOWL.COM, NS2.DNSOWL.COM, NS3.DNSOWL.COM]  2024-04-04 09:19:41
# 15             [NS1.ULTAHOST.MOBI, NS2.ULTAHOST.MOBI]  2024-04-02 07:45:43
# 16   [ns39.domaincontrol.com, ns40.domaincontrol.com]                  NaN
# 17   [ns1.dnsowl.com, ns2.dnsowl.com, ns3.dnsowl.com]                  NaN
# 18  [NS1.ULTAHOST.COM, NS2.ULTAHOST.COM, NS3.ULTAH...  2024-03-30 07:09:39
# 19  [DNS10.EXPIRENOTIFICATION.COM, DNS9.EXPIRENOTI...  2023-03-28 10:46:54
# 20               [NS1.ULTAHOST.LAT, NS2.ULTAHOST.LAT]                  NaN
# 21  [DNS1.REGISTRAR-SERVERS.COM, DNS2.REGISTRAR-SE...                  NaN
# 22  [ns1.ultahost.com, ns2.ultahost.com, ns3.ultah...  2024-03-31 07:57:41
# 23  [NITIN.NS.CLOUDFLARE.COM, STEVIE.NS.CLOUDFLARE...                  NaN
# 24  [colette.ns.cloudflare.com, ganz.ns.cloudflare...                  NaN
# 25  [DAMIAN.NS.CLOUDFLARE.COM, SAMARA.NS.CLOUDFLAR...                  NaN
# 26  [kenia.ns.cloudflare.com, kellen.ns.cloudflare...                  NaN
# 27                 [ns1.dyna-ns.net, ns2.dyna-ns.net]                  NaN
# 28   [NS1.DNSOWL.COM, NS2.DNSOWL.COM, NS3.DNSOWL.COM]  2024-04-06 10:22:20
# 29  [NS1.A2HOSTING.COM, NS2.A2HOSTING.COM, NS3.A2H...                  NaN
# 30   [NS1.DNSOWL.COM, NS2.DNSOWL.COM, NS3.DNSOWL.COM]  2024-04-05 09:27:19
# 31             [NS1.REG-NET79.COM, NS2.REG-NET79.COM]  2024-04-05 01:21:16
# 32   [NS1.DNSOWL.COM, NS2.DNSOWL.COM, NS3.DNSOWL.COM]                  NaN
# 33  [DARL.NS.CLOUDFLARE.COM, ROSA.NS.CLOUDFLARE.CO...                  NaN
#
#         expiration_date         updated_date             first_name_server  \
# 0                   NaN                  NaN                 NS2.BEGET.PRO
# 1   2025-04-07 15:11:53  2024-04-07 15:25:15        sean.ns.cloudflare.com
# 2   2025-04-03 10:18:48  2024-04-03 10:18:48                NS1.DNSOWL.COM
# 3   2025-04-06 23:59:59  2024-04-06 09:02:24     DNS1.NAMECHEAPHOSTING.COM
# 4                   NaN  2024-04-03 23:45:02            DNS1.P09.NSONE.NET
# 5                   NaN  2024-03-30 21:41:30        wren.ns.cloudflare.com
# 6                   NaN                  NaN      CULLEN.NS.CLOUDFLARE.COM
# 7   2025-04-05 06:40:43  2024-04-05 06:40:43                NS1.DNSOWL.COM
# 8   2025-03-25 02:22:01                  NaN         NS1.RENEWYOURNAME.NET
# 9                   NaN  2024-04-03 04:03:18     BARBARA.NS.CLOUDFLARE.COM
# 10  2025-04-03 12:12:03  2024-04-03 12:12:04   NS1.BDM.MICROSOFTONLINE.COM
# 11  2025-04-05 09:27:00  2024-04-05 09:27:00                NS1.DNSOWL.COM
# 12                  NaN  2024-04-02 12:03:44       ULLIS.NS.CLOUDFLARE.COM
# 13                  NaN  2024-04-02 06:31:34    DNS1.REGISTRAR-SERVERS.COM
# 14  2025-04-04 09:19:41  2024-04-04 09:19:41                NS1.DNSOWL.COM
# 15  2025-04-02 07:45:43  2024-04-09 10:53:05             NS1.ULTAHOST.MOBI
# 16                  NaN                  NaN        ns39.domaincontrol.com
# 17                  NaN                  NaN                ns1.dnsowl.com
# 18  2025-03-30 07:09:39  2024-03-31 07:29:47              NS1.ULTAHOST.COM
# 19  2025-03-28 10:46:54  2024-04-01 16:01:26  DNS10.EXPIRENOTIFICATION.COM
# 20                  NaN                  NaN              NS1.ULTAHOST.LAT
# 21                  NaN  2024-04-07 01:25:26    DNS1.REGISTRAR-SERVERS.COM
# 22  2025-03-31 07:57:41  2024-04-05 07:57:49              ns1.ultahost.com
# 23                  NaN                  NaN       NITIN.NS.CLOUDFLARE.COM
# 24                  NaN                  NaN     colette.ns.cloudflare.com
# 25                  NaN  2024-03-29 07:54:48      DAMIAN.NS.CLOUDFLARE.COM
# 26                  NaN  2024-03-29 04:50:45       kenia.ns.cloudflare.com
# 27                  NaN  2024-04-05 07:52:14               ns1.dyna-ns.net
# 28  2025-04-06 10:22:20  2024-04-06 10:22:21                NS1.DNSOWL.COM
# 29                  NaN                  NaN             NS1.A2HOSTING.COM
# 30  2025-04-05 09:27:19  2024-04-05 09:27:19                NS1.DNSOWL.COM
# 31                  NaN  2024-04-05 01:21:17             NS1.REG-NET79.COM
# 32                  NaN                  NaN                NS1.DNSOWL.COM
# 33                  NaN                  NaN        DARL.NS.CLOUDFLARE.COM
#
#              second_name_server domain_tld
# 0                 NS2.BEGET.COM         pw
# 1        kira.ns.cloudflare.com       buzz
# 2                NS2.DNSOWL.COM        net
# 3     DNS2.NAMECHEAPHOSTING.COM        xyz
# 4            DNS2.P09.NSONE.NET        net
# 5       margo.ns.cloudflare.com     africa
# 6         LIA.NS.CLOUDFLARE.COM       shop
# 7                NS2.DNSOWL.COM        net
# 8         NS2.RENEWYOURNAME.NET        com
# 9      LENNON.NS.CLOUDFLARE.COM        com
# 10  NS2.BDM.MICROSOFTONLINE.COM        com
# 11               NS2.DNSOWL.COM        com
# 12       VERN.NS.CLOUDFLARE.COM        com
# 13   DNS2.REGISTRAR-SERVERS.COM       site
# 14               NS2.DNSOWL.COM        com
# 15            NS2.ULTAHOST.MOBI        com
# 16       ns40.domaincontrol.com       info
# 17               ns2.dnsowl.com        org
# 18             NS2.ULTAHOST.COM        com
# 19  DNS9.EXPIRENOTIFICATION.COM        com
# 20             NS2.ULTAHOST.LAT        net
# 21   DNS2.REGISTRAR-SERVERS.COM        com
# 22             ns2.ultahost.com        org
# 23     STEVIE.NS.CLOUDFLARE.COM       shop
# 24       ganz.ns.cloudflare.com        org
# 25     SAMARA.NS.CLOUDFLARE.COM        com
# 26     kellen.ns.cloudflare.com         co
# 27              ns2.dyna-ns.net        bet
# 28               NS2.DNSOWL.COM        com
# 29            NS2.A2HOSTING.COM        com
# 30               NS2.DNSOWL.COM        net
# 31            NS2.REG-NET79.COM        com
# 32               NS2.DNSOWL.COM        com
# 33       ROSA.NS.CLOUDFLARE.COM        com

# %% [markdown]
# #### Must've overloaded the whois server, only got info for 34 domains, bummer

# %% [markdown]
# #### Convert dates to datetime objects

# %%
df['expiration_date_parsed'] = pd.to_datetime(df['creation_date'], format='mixed')
df['expiration_date_parsed'] = pd.to_datetime(df['creation_date'], format='mixed')
df['updated_date_parsed'] = pd.to_datetime(df['updated_date'], format='mixed')

# %% [markdown]
# #### What are the most common tlds?

# %%
df['domain_tld'].value_counts()
# Out:
# domain_tld
# com       16
# net        5
# org        3
# shop       2
# pw         1
# buzz       1
# xyz        1
# africa     1
# site       1
# info       1
# co         1
# bet        1
# Name: count, dtype: int64

# %% [markdown]
# #### The next step in automating this analysis could be to pivot on information for the domains flagged for phishing.
#
# #### For example, the ip hosting login-soport-icloud[.]us, 162.240.148[.]126, appears to host several other suspicious domains.
